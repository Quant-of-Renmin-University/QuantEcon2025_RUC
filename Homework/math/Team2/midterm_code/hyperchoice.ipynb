# %%
mountedDB = {}

# %% [markdown]
# ## 欢迎进入 Notebook
#
# 这里你可以编写代码，文档
#
# ### 关于文件目录
#
#
# **project**：project 目录是本项目的工作空间，可以把将项目运行有关的所有文件放在这里，目录中文件的增、删、改操作都会被保留
#
#
# **input**：input 目录是数据集的挂载位置，所有挂载进项目的数据集都在这里，未挂载数据集时 input 目录被隐藏
#
#
# **temp**：temp 目录是临时磁盘空间，训练或分析过程中产生的不必要文件可以存放在这里，目录中的文件不会保存

# %%
# 查看个人持久化工作区文件
# !ls /home/mw/project/
# Out:
# details.parquet  rent.parquet  test.parquet  train.parquet  train_plus.parquet

# %%
# 查看当前挂载的数据集目录
# !ls /home/mw/input/
# Out:
# __init__.py  quant4533

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures

df = pd.read_parquet('/home/mw/project/train_plus.parquet')

# 数据预处理
# 转换需要作为分类变量的列
df['城市'] = df['城市'].astype('category')
df['区域'] = df['区域'].astype('category')
df['板块'] = df['板块'].astype('category')

# 定义特征和标签
X = df.drop(columns=['价格', '小区名称', '交易时间'])
y = df['价格']

# 划分训练集和测试集
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=111)

# 定义预处理器
numeric_features = X.select_dtypes(include=['int32', 'int64', 'float64']).columns.tolist()
categorical_features = X.select_dtypes(include=['category']).columns.tolist()

preprocessor = ColumnTransformer([
    ('num', Pipeline([
        ('scaler', StandardScaler()),
        ('poly', PolynomialFeatures(degree=2, interaction_only=True))  # 二次项
    ]), numeric_features),
    ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_features)
])

# %%
from sklearn.model_selection import GridSearchCV

# 更新模型管道
models = {
    'Lasso': Pipeline([
        ('preprocessor', preprocessor),
        ('regressor', Lasso(random_state=111))
    ]),
    'Ridge': Pipeline([
        ('preprocessor', preprocessor),
        ('regressor', Ridge(random_state=111))
    ]),
    'ElasticNet': Pipeline([
        ('preprocessor', preprocessor),
        ('regressor', ElasticNet(random_state=111))
    ])
}

# 参数网格
param_grids = {
    'Lasso': {
        'regressor__alpha': [0.001, 0.01, 0.1, 1, 10],
        'regressor__max_iter': [5000, 10000],
        'regressor__tol': [1e-4, 1e-5]
    },
    'Ridge': {
        'regressor__alpha': [0.1, 1, 10, 100, 1000]
    },
    'ElasticNet': {
        'regressor__alpha': [0.001, 0.01, 0.1, 1],
        'regressor__l1_ratio': [0.2, 0.5, 0.8],
        'regressor__max_iter': [5000, 10000]
    }
}

# 执行网格搜索
best_models = {}
for name in models.keys():
    grid_search = GridSearchCV(models[name], param_grids[name], 
                              cv=5, scoring='neg_mean_squared_error',
                              n_jobs=-1, verbose=1)
    grid_search.fit(X_train, y_train)
    best_models[name] = grid_search.best_estimator_
    print(f"{name} best params: {grid_search.best_params_}")
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.563e+15, tolerance: 1.421e+12
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.631e+15, tolerance: 1.413e+12
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.560e+15, tolerance: 1.407e+12
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.507e+15, tolerance: 1.402e+12
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.476e+15, tolerance: 1.405e+12
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.563e+15, tolerance: 1.421e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.631e+15, tolerance: 1.413e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.560e+15, tolerance: 1.407e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.476e+15, tolerance: 1.405e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.507e+15, tolerance: 1.402e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.507e+15, tolerance: 1.402e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.506e+15, tolerance: 1.402e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.630e+15, tolerance: 1.413e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.629e+15, tolerance: 1.413e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.507e+15, tolerance: 1.402e+12
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.559e+15, tolerance: 1.407e+12
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.630e+15, tolerance: 1.413e+12
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.475e+15, tolerance: 1.405e+12
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.562e+15, tolerance: 1.421e+12
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.559e+15, tolerance: 1.407e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.475e+15, tolerance: 1.405e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.562e+15, tolerance: 1.421e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.629e+15, tolerance: 1.413e+12
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.506e+15, tolerance: 1.402e+12
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.558e+15, tolerance: 1.407e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.558e+15, tolerance: 1.407e+12
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.474e+15, tolerance: 1.405e+12
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.474e+15, tolerance: 1.405e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.561e+15, tolerance: 1.421e+12
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.561e+15, tolerance: 1.421e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.490e+15, tolerance: 1.402e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.611e+15, tolerance: 1.413e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.629e+15, tolerance: 1.413e+12
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.505e+15, tolerance: 1.402e+12
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.473e+15, tolerance: 1.405e+12
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.557e+15, tolerance: 1.407e+12
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.560e+15, tolerance: 1.421e+12
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.505e+15, tolerance: 1.402e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.629e+15, tolerance: 1.413e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.473e+15, tolerance: 1.405e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.557e+15, tolerance: 1.407e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.560e+15, tolerance: 1.421e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.541e+15, tolerance: 1.407e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.490e+15, tolerance: 1.402e+12
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.457e+15, tolerance: 1.405e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.611e+15, tolerance: 1.413e+12
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.457e+15, tolerance: 1.405e+12
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.541e+15, tolerance: 1.407e+12
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.541e+15, tolerance: 1.421e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.541e+15, tolerance: 1.421e+12
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.420e+15, tolerance: 1.413e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.309e+15, tolerance: 1.402e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.611e+15, tolerance: 1.413e+12
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.541e+15, tolerance: 1.407e+12
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.489e+15, tolerance: 1.402e+12
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.456e+15, tolerance: 1.405e+12
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.489e+15, tolerance: 1.402e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.541e+15, tolerance: 1.421e+12
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.541e+15, tolerance: 1.407e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.611e+15, tolerance: 1.413e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.456e+15, tolerance: 1.405e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.541e+15, tolerance: 1.421e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.309e+15, tolerance: 1.402e+12
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.420e+15, tolerance: 1.413e+12
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.257e+15, tolerance: 1.405e+12
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.257e+15, tolerance: 1.405e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.353e+15, tolerance: 1.421e+12
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.351e+15, tolerance: 1.407e+12
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.351e+15, tolerance: 1.407e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.353e+15, tolerance: 1.421e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.201e+15, tolerance: 1.413e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.390e+14, tolerance: 1.402e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.424e+15, tolerance: 1.413e+12
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.353e+15, tolerance: 1.407e+12
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.326e+15, tolerance: 1.421e+12
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.242e+15, tolerance: 1.405e+12
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.310e+15, tolerance: 1.402e+12
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.310e+15, tolerance: 1.402e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.424e+15, tolerance: 1.413e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.353e+15, tolerance: 1.407e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.242e+15, tolerance: 1.405e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.326e+15, tolerance: 1.421e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.474e+15, tolerance: 1.407e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.028e+15, tolerance: 1.405e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.390e+14, tolerance: 1.402e+12
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.474e+15, tolerance: 1.407e+12
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.028e+15, tolerance: 1.405e+12
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.201e+15, tolerance: 1.413e+12
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.086e+15, tolerance: 1.421e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.086e+15, tolerance: 1.421e+12
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.421e+14, tolerance: 1.402e+12
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.894e+14, tolerance: 1.407e+12
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.894e+14, tolerance: 1.407e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.770e+15, tolerance: 1.413e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.203e+14, tolerance: 1.405e+12
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.478e+15, tolerance: 1.421e+12
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.421e+14, tolerance: 1.402e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.770e+15, tolerance: 1.413e+12
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.478e+15, tolerance: 1.421e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.203e+14, tolerance: 1.405e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.732e+15, tolerance: 1.762e+13
#   model = cd_fast.enet_coordinate_descent(
# Lasso best params: {'regressor__alpha': 1, 'regressor__max_iter': 10000, 'regressor__tol': 0.0001}
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# /opt/conda/lib/python3.9/site-packages/sklearn/utils/extmath.py:193: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /opt/conda/lib/python3.9/site-packages/sklearn/utils/extmath.py:193: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /opt/conda/lib/python3.9/site-packages/sklearn/utils/extmath.py:193: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /opt/conda/lib/python3.9/site-packages/sklearn/utils/extmath.py:193: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /opt/conda/lib/python3.9/site-packages/sklearn/utils/extmath.py:193: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /opt/conda/lib/python3.9/site-packages/sklearn/utils/extmath.py:193: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /opt/conda/lib/python3.9/site-packages/sklearn/utils/extmath.py:193: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /opt/conda/lib/python3.9/site-packages/sklearn/utils/extmath.py:193: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /opt/conda/lib/python3.9/site-packages/sklearn/utils/extmath.py:193: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /opt/conda/lib/python3.9/site-packages/sklearn/utils/extmath.py:193: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /opt/conda/lib/python3.9/site-packages/sklearn/utils/extmath.py:193: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /opt/conda/lib/python3.9/site-packages/sklearn/utils/extmath.py:193: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /opt/conda/lib/python3.9/site-packages/sklearn/utils/extmath.py:193: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /opt/conda/lib/python3.9/site-packages/sklearn/utils/extmath.py:193: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /opt/conda/lib/python3.9/site-packages/sklearn/utils/extmath.py:193: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /opt/conda/lib/python3.9/site-packages/sklearn/utils/extmath.py:193: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /opt/conda/lib/python3.9/site-packages/sklearn/utils/extmath.py:193: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /opt/conda/lib/python3.9/site-packages/sklearn/utils/extmath.py:193: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /opt/conda/lib/python3.9/site-packages/sklearn/utils/extmath.py:193: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /opt/conda/lib/python3.9/site-packages/sklearn/utils/extmath.py:193: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /opt/conda/lib/python3.9/site-packages/sklearn/utils/extmath.py:193: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /opt/conda/lib/python3.9/site-packages/sklearn/utils/extmath.py:193: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /opt/conda/lib/python3.9/site-packages/sklearn/utils/extmath.py:193: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /opt/conda/lib/python3.9/site-packages/sklearn/utils/extmath.py:193: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /opt/conda/lib/python3.9/site-packages/sklearn/utils/extmath.py:193: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /opt/conda/lib/python3.9/site-packages/sklearn/utils/extmath.py:193: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# Ridge best params: {'regressor__alpha': 0.1}
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.972e+15, tolerance: 1.421e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.917e+15, tolerance: 1.407e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.862e+15, tolerance: 1.405e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.906e+15, tolerance: 1.402e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.530e+15, tolerance: 1.413e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.398e+15, tolerance: 1.402e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.041e+15, tolerance: 1.413e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.353e+15, tolerance: 1.405e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.415e+15, tolerance: 1.407e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.786e+15, tolerance: 1.413e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.457e+15, tolerance: 1.421e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.714e+15, tolerance: 1.421e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.558e+15, tolerance: 1.405e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.533e+15, tolerance: 1.402e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.699e+15, tolerance: 1.407e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.774e+15, tolerance: 1.413e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.646e+15, tolerance: 1.402e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.671e+15, tolerance: 1.407e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.694e+15, tolerance: 1.421e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.601e+15, tolerance: 1.405e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.354e+15, tolerance: 1.407e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.456e+15, tolerance: 1.413e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.310e+15, tolerance: 1.402e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.265e+15, tolerance: 1.405e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.386e+15, tolerance: 1.421e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.632e+15, tolerance: 1.402e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.760e+15, tolerance: 1.413e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.661e+15, tolerance: 1.407e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.588e+15, tolerance: 1.405e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.684e+15, tolerance: 1.421e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.311e+14, tolerance: 1.402e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.184e+14, tolerance: 1.413e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.509e+14, tolerance: 1.407e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.189e+14, tolerance: 1.405e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.105e+15, tolerance: 1.421e+13
#   model = cd_fast.enet_coordinate_descent(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.391e+15, tolerance: 1.762e+13
#   model = cd_fast.enet_coordinate_descent(
# ElasticNet best params: {'regressor__alpha': 0.001, 'regressor__l1_ratio': 0.8, 'regressor__max_iter': 10000}
