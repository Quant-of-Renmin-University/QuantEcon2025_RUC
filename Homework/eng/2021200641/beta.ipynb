# %%
# Fama & French 3 factors residual variance
# Note: Please use the latest version of pandas, this version should support returning to pd.Series after rolling
# To get a faster speed, we split the big dataframe into small ones
# Then using different process to calculate the variance
# We use 20 process to calculate variance, you can change the number of process according to your CPU situation
# You can use the following code to check your CPU situation
# import multiprocessing
# multiprocessing.cpu_count()

import pandas as pd
import numpy as np
import datetime as dt
import wrds
from dateutil.relativedelta import *
from pandas.tseries.offsets import *
import datetime
import pickle as pkl
import statsmodels.api as sm
import pyarrow.feather as feather
import multiprocessing as mp

# %% [markdown]
# 1. Beta

# %%
crsp = pd.read_feather("raw_data/crsp_beta.ftr")

# %%
# sort variables by permno and date
crsp = crsp.sort_values(by=['permno', 'date'])

# change variable format to int
crsp['permno'] = crsp['permno'].astype(int)

# Line up date to be end of month
crsp['date'] = pd.to_datetime(crsp['date'])

# add delisting return
dlret = pd.read_feather("dlret.ftr")

dlret.permno = dlret.permno.astype(int)
dlret['dlstdt'] = pd.to_datetime(dlret['dlstdt'])
dlret['date'] = dlret['dlstdt']

# merge delisting return to crsp return
crsp = pd.merge(crsp, dlret, how='left', on=['permno', 'date'])
crsp['dlret'] = crsp['dlret'].fillna(0)
crsp['ret'] = crsp['ret'].fillna(0)
crsp['retadj'] = (1 + crsp['ret']) * (1 + crsp['dlret']) - 1
crsp['exret'] = crsp['retadj'] - crsp['rf']

# %%
# find the closest trading day to the end of the month
crsp['monthend'] = crsp['date'] + MonthEnd(0)
crsp['date_diff'] = crsp['monthend'] - crsp['date']
date_temp = crsp.groupby(['permno', 'monthend'])['date_diff'].min()
date_temp = pd.DataFrame(date_temp)  # convert Series to DataFrame
date_temp.reset_index(inplace=True)
date_temp.rename(columns={'date_diff': 'min_diff'}, inplace=True)
crsp = pd.merge(crsp, date_temp, how='left', on=['permno', 'monthend'])
crsp['sig'] = np.where(crsp['date_diff'] == crsp['min_diff'], 1, np.nan)

# label every date of month end
crsp['month_count'] = crsp[crsp['sig'] == 1].groupby(['permno']).cumcount()

# label numbers of months for a firm
month_num = crsp[crsp['sig'] == 1].groupby(['permno'])['month_count'].tail(1)
month_num = month_num.astype(int)
month_num = month_num.reset_index(drop=True)

# mark the number of each month to each day of this month
crsp['month_count'] = crsp.groupby(['permno'])['month_count'].fillna(method='bfill')

# crate a firm list
df_firm = crsp.drop_duplicates(['permno'])
df_firm = df_firm[['permno']]
df_firm['permno'] = df_firm['permno'].astype(int)
df_firm = df_firm.reset_index(drop=True)
df_firm = df_firm.reset_index()
df_firm = df_firm.rename(columns={'index': 'count'})
df_firm['month_num'] = month_num
# Out:
# /var/folders/09/pqd87cvj3kjbrvbzxrht87d80000gn/T/ipykernel_95173/87601466.py:20: FutureWarning: SeriesGroupBy.fillna is deprecated and will be removed in a future version. Use obj.ffill() or obj.bfill() for forward or backward filling instead. If you want to fill with a single value, use Series.fillna instead
#   crsp['month_count'] = crsp.groupby(['permno'])['month_count'].fillna(method='bfill')
# /var/folders/09/pqd87cvj3kjbrvbzxrht87d80000gn/T/ipykernel_95173/87601466.py:20: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   crsp['month_count'] = crsp.groupby(['permno'])['month_count'].fillna(method='bfill')

# %%
######################
# Calculate the beta #
######################
def get_beta(df, firm_list):
    """
    :param df: stock dataframe
    :param firm_list: list of firms matching stock dataframe
    :return: dataframe with variance of residual
    """
    half_life = 1.5  # 半衰期设为一个半月(rolling window为三个月)
    for firm, count, prog in zip(firm_list['permno'], firm_list['month_num'], range(firm_list['permno'].count() + 1)):
        prog = prog + 1
        print('processing permno %s' % firm, '/', 'finished', '%.2f%%' % ((prog / firm_list['permno'].count()) * 100))
        for i in range(count + 1):
            # if you want to change the rolling window, please change here: i - 2 means 3 months is a window.
            temp = df[(df['permno'] == firm) & (i - 2 <= df['month_count']) & (df['month_count'] <= i)]
            # if observations in last 3 months are less 21, we drop the rvar of this month
            if temp['permno'].count() < 21:
                continue
            else:
                rolling_window = temp['permno'].count()
                index = temp.tail(1).index
                X = temp[['mktrf']]
                Y = temp['exret']

                # 计算指数衰减权重
                time_differences = np.arange(rolling_window)[::-1]  # 从当前时间点往前的时间差
                weights = 0.5 ** (time_differences / half_life)

                # 添加常数项
                X = sm.add_constant(X)

                # 加权最小二乘回归
                model = sm.WLS(Y, X, weights=weights)
                results = model.fit()

                # beta
                beta = results.params['mktrf']
                df.loc[index, 'beta'] = beta
    return df


def sub_df(start, end, step):
    """
    :param start: the quantile to start cutting, usually it should be 0
    :param end: the quantile to end cutting, usually it should be 1
    :param step: quantile step
    :return: a dictionary including all the 'firm_list' dataframe and 'newly grouped stock data' dataframe
    """
    # 按照原来的逻辑先分10组
    temp = {}
    for i, h in zip(np.arange(start, end, step), range(int((end - start) / step))):
        print('processing splitting dataframe:', round(i, 2), 'to', round(i + step, 2))
        if i == 0:  # to get the left point
            temp['firm' + str(h)] = df_firm[df_firm['month_count'] <= df_firm['month_count'].quantile(i + step)]
            temp['crsp' + str(h)] = pd.merge(crsp, temp['firm' + str(h)], how='left',
                                             on='permno').dropna(subset=['month_count'])
        else:
            temp['firm' + str(h)] = df_firm[(df_firm['month_count'].quantile(i) < df_firm['month_count']) & (
                    df_firm['month_count'] <= df_firm['month_count'].quantile(i + step))]
            temp['crsp' + str(h)] = pd.merge(crsp, temp['firm' + str(h)], how='left',
                                             on='permno').dropna(subset=['month_count'])

    # 初始化新的10组df
    new_groups = {f'new_group_{i}': pd.DataFrame() for i in range(10)}

    # 将原来的10组数据均匀地分配到新的10组中，可以确保每个df的计算进度相近
    for key in temp:
        if key.startswith('crsp'):
            group_data = temp[key]
            for i, row in group_data.iterrows():
                new_group_index = len(new_groups[f'new_group_{i % 10}'])
                new_groups[f'new_group_{i % 10}'] = new_groups[f'new_group_{i % 10}'].append(row, ignore_index=True)

    return new_groups


def process(start, end, step):
    """

    :param start: the quantile to start cutting, usually it should be 0
    :param end: the quantile to end cutting, usually it should be 1
    :param step: quantile step
    :return: a dataframe with calculated variance of residual
    """
    df = sub_df(start, end, step)
    pool = mp.Pool()
    p_dict = {}
    for i in range(int((end-start)/step)):
        p_dict['p' + str(i)] = pool.apply_async(get_beta, (df['crsp%s' % i], df['firm%s' % i],))
    pool.close()
    pool.join()
    result = pd.DataFrame()
    print('processing pd.concat')
    for h in range(int((end-start)/step)):
        result = pd.concat([result, p_dict['p%s' % h].get()])
    return result


# calculate variance of residual through rolling window
# Note: please split dataframe according to your CPU situation. For example, we split dataframe to (1-0)/0.05 = 20 sub
# dataframes here, so the function will use 20 cores to calculate variance of residual.
crsp = process(0, 1, 0.125)
# Out:
# processing splitting dataframe: 0.0 to 0.12
# processing splitting dataframe: 0.12 to 0.25
# processing splitting dataframe: 0.25 to 0.38
# processing splitting dataframe: 0.38 to 0.5
# processing splitting dataframe: 0.5 to 0.62
# processing splitting dataframe: 0.62 to 0.75
# processing splitting dataframe: 0.75 to 0.88
# processing splitting dataframe: 0.88 to 1.0
# Processing chunk 1/8
# processing permno 10001 / finished 0.05%
# processing permno 10025 / finished 0.11%
# processing permno 10026 / finished 0.16%
# processing permno 10028 / finished 0.22%
# processing permno 10032 / finished 0.27%
# processing permno 10044 / finished 0.32%
# processing permno 10051 / finished 0.38%
# processing permno 10065 / finished 0.43%
# processing permno 10066 / finished 0.48%
# processing permno 10104 / finished 0.54%
# processing permno 10107 / finished 0.59%
# processing permno 10113 / finished 0.65%
# processing permno 10116 / finished 0.70%
# processing permno 10138 / finished 0.75%
# processing permno 10145 / finished 0.81%
# processing permno 10147 / finished 0.86%
# processing permno 10158 / finished 0.92%
# processing permno 10180 / finished 0.97%
# processing permno 10182 / finished 1.02%
# processing permno 10200 / finished 1.08%
# processing permno 10201 / finished 1.13%
# processing permno 10207 / finished 1.18%
# processing permno 10220 / finished 1.24%
# processing permno 10232 / finished 1.29%
# processing permno 10239 / finished 1.35%
# processing permno 10252 / finished 1.40%
# processing permno 10253 / finished 1.45%
# processing permno 10257 / finished 1.51%
# processing permno 10258 / finished 1.56%
# processing permno 10259 / finished 1.62%
# processing permno 10294 / finished 1.67%
# processing permno 10297 / finished 1.72%
# processing permno 10299 / finished 1.78%
# processing permno 10302 / finished 1.83%
# processing permno 10308 / finished 1.88%
# processing permno 10318 / finished 1.94%
# processing permno 10333 / finished 1.99%
# processing permno 10353 / finished 2.05%
# processing permno 10355 / finished 2.10%
# processing permno 10363 / finished 2.15%
# processing permno 10375 / finished 2.21%
# processing permno 10382 / finished 2.26%
# processing permno 10395 / finished 2.32%
# processing permno 10397 / finished 2.37%
# processing permno 10421 / finished 2.42%
# processing permno 10443 / finished 2.48%
# processing permno 10463 / finished 2.53%
# processing permno 10501 / finished 2.58%
# processing permno 10514 / finished 2.64%
# processing permno 10516 / finished 2.69%
# processing permno 10517 / finished 2.75%
# processing permno 10530 / finished 2.80%
# processing permno 10547 / finished 2.85%
# processing permno 10550 / finished 2.91%
# processing permno 10606 / finished 2.96%
# processing permno 10629 / finished 3.02%
# processing permno 10645 / finished 3.07%
# processing permno 10649 / finished 3.12%
# processing permno 10656 / finished 3.18%
# processing permno 10661 / finished 3.23%
# processing permno 10667 / finished 3.28%
# processing permno 10693 / finished 3.34%
# processing permno 10696 / finished 3.39%
# processing permno 10777 / finished 3.45%
# processing permno 10779 / finished 3.50%
# processing permno 10781 / finished 3.55%
# processing permno 10812 / finished 3.61%
# processing permno 10838 / finished 3.66%
# processing permno 10853 / finished 3.72%
# processing permno 10860 / finished 3.77%
# processing permno 10866 / finished 3.82%
# processing permno 10874 / finished 3.88%
# processing permno 10886 / finished 3.93%
# processing permno 10890 / finished 3.98%
# processing permno 10892 / finished 4.04%
# processing permno 10901 / finished 4.09%
# processing permno 10909 / finished 4.15%
# processing permno 10913 / finished 4.20%
# processing permno 10932 / finished 4.25%
# processing permno 10933 / finished 4.31%
# processing permno 10952 / finished 4.36%
# processing permno 10966 / finished 4.42%
# processing permno 11003 / finished 4.47%
# processing permno 11006 / finished 4.52%
# processing permno 11018 / finished 4.58%
# processing permno 11043 / finished 4.63%
# processing permno 11144 / finished 4.68%
# processing permno 11153 / finished 4.74%
# processing permno 11154 / finished 4.79%
# processing permno 11174 / finished 4.85%
# processing permno 11182 / finished 4.90%
# processing permno 11203 / finished 4.95%
# processing permno 11208 / finished 5.01%
# processing permno 11246 / finished 5.06%
# processing permno 11264 / finished 5.12%
# processing permno 11267 / finished 5.17%
# processing permno 11275 / finished 5.22%
# processing permno 11285 / finished 5.28%
# processing permno 11292 / finished 5.33%
# processing permno 11293 / finished 5.39%
# processing permno 11308 / finished 5.44%
# processing permno 11343 / finished 5.49%
# processing permno 11348 / finished 5.55%
# processing permno 11361 / finished 5.60%
# processing permno 11363 / finished 5.65%
# processing permno 11368 / finished 5.71%
# processing permno 11369 / finished 5.76%
# processing permno 11370 / finished 5.82%
# processing permno 11378 / finished 5.87%
# processing permno 11379 / finished 5.92%
# processing permno 11394 / finished 5.98%
# processing permno 11397 / finished 6.03%
# processing permno 11403 / finished 6.09%
# processing permno 11404 / finished 6.14%
# processing permno 11407 / finished 6.19%
# processing permno 11441 / finished 6.25%
# processing permno 11442 / finished 6.30%
# processing permno 11481 / finished 6.35%
# processing permno 11499 / finished 6.41%
# processing permno 11511 / finished 6.46%
# processing permno 11533 / finished 6.52%
# processing permno 11547 / finished 6.57%
# processing permno 11552 / finished 6.62%
# processing permno 11565 / finished 6.68%
# processing permno 11581 / finished 6.73%
# processing permno 11587 / finished 6.79%
# processing permno 11593 / finished 6.84%
# processing permno 11600 / finished 6.89%
# processing permno 11618 / finished 6.95%
# processing permno 11628 / finished 7.00%
# processing permno 11636 / finished 7.05%
# processing permno 11638 / finished 7.11%
# processing permno 11641 / finished 7.16%
# processing permno 11644 / finished 7.22%
# processing permno 11648 / finished 7.27%
# processing permno 11654 / finished 7.32%
# processing permno 11664 / finished 7.38%
# processing permno 11674 / finished 7.43%
# processing permno 11691 / finished 7.49%
# processing permno 11701 / finished 7.54%
# processing permno 11703 / finished 7.59%
# processing permno 11707 / finished 7.65%
# processing permno 11731 / finished 7.70%
# processing permno 11748 / finished 7.75%
# processing permno 11750 / finished 7.81%
# processing permno 11752 / finished 7.86%
# processing permno 11762 / finished 7.92%
# processing permno 11775 / finished 7.97%
# processing permno 11786 / finished 8.02%
# processing permno 11790 / finished 8.08%
# processing permno 11803 / finished 8.13%
# processing permno 11809 / finished 8.19%
# processing permno 11825 / finished 8.24%
# processing permno 11844 / finished 8.29%
# processing permno 11845 / finished 8.35%
# processing permno 11850 / finished 8.40%
# processing permno 11884 / finished 8.45%
# processing permno 11891 / finished 8.51%
# processing permno 11896 / finished 8.56%
# processing permno 11955 / finished 8.62%
# processing permno 11990 / finished 8.67%
# processing permno 11992 / finished 8.72%
# processing permno 11995 / finished 8.78%
# processing permno 11996 / finished 8.83%
# processing permno 12007 / finished 8.89%
# processing permno 12008 / finished 8.94%
# processing permno 12009 / finished 8.99%
# processing permno 12011 / finished 9.05%
# processing permno 12015 / finished 9.10%
# processing permno 12017 / finished 9.15%
# processing permno 12018 / finished 9.21%
# processing permno 12023 / finished 9.26%
# processing permno 12026 / finished 9.32%
# processing permno 12027 / finished 9.37%
# processing permno 12030 / finished 9.42%
# processing permno 12034 / finished 9.48%
# processing permno 12035 / finished 9.53%
# processing permno 12036 / finished 9.59%
# processing permno 12039 / finished 9.64%
# processing permno 12047 / finished 9.69%
# processing permno 12049 / finished 9.75%
# processing permno 12051 / finished 9.80%
# processing permno 12052 / finished 9.85%
# processing permno 12054 / finished 9.91%
# processing permno 12057 / finished 9.96%
# processing permno 12059 / finished 10.02%
# processing permno 12060 / finished 10.07%
# processing permno 12062 / finished 10.12%
# processing permno 12064 / finished 10.18%
# processing permno 12065 / finished 10.23%
# processing permno 12066 / finished 10.29%
# processing permno 12068 / finished 10.34%
# processing permno 12070 / finished 10.39%
# processing permno 12072 / finished 10.45%
# processing permno 12073 / finished 10.50%
# processing permno 12075 / finished 10.55%
# processing permno 12076 / finished 10.61%
# processing permno 12078 / finished 10.66%
# processing permno 12080 / finished 10.72%
# processing permno 12082 / finished 10.77%
# processing permno 12084 / finished 10.82%
# processing permno 12088 / finished 10.88%
# processing permno 12089 / finished 10.93%
# processing permno 12093 / finished 10.99%
# processing permno 12097 / finished 11.04%
# processing permno 12098 / finished 11.09%
# processing permno 12103 / finished 11.15%
# processing permno 12105 / finished 11.20%
# processing permno 12109 / finished 11.25%
# processing permno 12146 / finished 11.31%
# processing permno 12149 / finished 11.36%
# processing permno 12166 / finished 11.42%
# processing permno 12173 / finished 11.47%
# processing permno 12189 / finished 11.52%
# processing permno 12190 / finished 11.58%
# processing permno 12209 / finished 11.63%
# processing permno 12211 / finished 11.69%
# processing permno 12219 / finished 11.74%
# processing permno 12226 / finished 11.79%
# processing permno 12248 / finished 11.85%
# processing permno 12266 / finished 11.90%
# processing permno 12287 / finished 11.95%
# processing permno 12288 / finished 12.01%
# processing permno 12289 / finished 12.06%
# processing permno 12292 / finished 12.12%
# processing permno 12293 / finished 12.17%
# processing permno 12294 / finished 12.22%
# processing permno 12295 / finished 12.28%
# processing permno 12296 / finished 12.33%
# processing permno 12297 / finished 12.39%
# processing permno 12301 / finished 12.44%
# processing permno 12302 / finished 12.49%
# processing permno 12303 / finished 12.55%
# processing permno 12304 / finished 12.60%
# processing permno 12305 / finished 12.65%
# processing permno 12306 / finished 12.71%
# processing permno 12307 / finished 12.76%
# processing permno 12308 / finished 12.82%
# processing permno 12309 / finished 12.87%
# processing permno 12310 / finished 12.92%
# processing permno 12312 / finished 12.98%
# processing permno 12313 / finished 13.03%
# processing permno 12314 / finished 13.09%
# processing permno 12315 / finished 13.14%
# processing permno 12316 / finished 13.19%
# processing permno 12317 / finished 13.25%
# processing permno 12318 / finished 13.30%
# processing permno 12321 / finished 13.35%
# processing permno 12322 / finished 13.41%
# processing permno 12323 / finished 13.46%
# processing permno 12324 / finished 13.52%
# processing permno 12325 / finished 13.57%
# processing permno 12326 / finished 13.62%
# processing permno 12329 / finished 13.68%
# processing permno 12330 / finished 13.73%
# processing permno 12331 / finished 13.79%
# processing permno 12332 / finished 13.84%
# processing permno 12333 / finished 13.89%
# processing permno 12334 / finished 13.95%
# processing permno 12338 / finished 14.00%
# processing permno 12339 / finished 14.05%
# processing permno 12340 / finished 14.11%
# processing permno 12341 / finished 14.16%
# processing permno 12345 / finished 14.22%
# processing permno 12347 / finished 14.27%
# processing permno 12348 / finished 14.32%
# processing permno 12350 / finished 14.38%
# processing permno 12352 / finished 14.43%
# processing permno 12355 / finished 14.49%
# processing permno 12356 / finished 14.54%
# processing permno 12357 / finished 14.59%
# processing permno 12358 / finished 14.65%
# processing permno 12360 / finished 14.70%
# processing permno 12362 / finished 14.75%
# processing permno 12363 / finished 14.81%
# processing permno 12365 / finished 14.86%
# processing permno 12366 / finished 14.92%
# processing permno 12367 / finished 14.97%
# processing permno 12368 / finished 15.02%
# processing permno 12369 / finished 15.08%
# processing permno 12370 / finished 15.13%
# processing permno 12371 / finished 15.19%
# processing permno 12372 / finished 15.24%
# processing permno 12373 / finished 15.29%
# processing permno 12374 / finished 15.35%
# processing permno 12376 / finished 15.40%
# processing permno 12377 / finished 15.46%
# processing permno 12379 / finished 15.51%
# processing permno 12380 / finished 15.56%
# processing permno 12384 / finished 15.62%
# processing permno 12385 / finished 15.67%
# processing permno 12389 / finished 15.72%
# processing permno 12390 / finished 15.78%
# processing permno 12391 / finished 15.83%
# processing permno 12392 / finished 15.89%
# processing permno 12397 / finished 15.94%
# processing permno 12400 / finished 15.99%
# processing permno 12402 / finished 16.05%
# processing permno 12405 / finished 16.10%
# processing permno 12410 / finished 16.16%
# processing permno 12411 / finished 16.21%
# processing permno 12412 / finished 16.26%
# processing permno 12413 / finished 16.32%
# processing permno 12431 / finished 16.37%
# processing permno 12437 / finished 16.42%
# processing permno 12438 / finished 16.48%
# processing permno 12442 / finished 16.53%
# processing permno 12443 / finished 16.59%
# processing permno 12444 / finished 16.64%
# processing permno 12445 / finished 16.69%
# processing permno 12446 / finished 16.75%
# processing permno 12447 / finished 16.80%
# processing permno 12448 / finished 16.86%
# processing permno 12449 / finished 16.91%
# processing permno 12451 / finished 16.96%
# processing permno 12452 / finished 17.02%
# processing permno 12453 / finished 17.07%
# processing permno 12457 / finished 17.12%
# processing permno 12461 / finished 17.18%
# processing permno 12462 / finished 17.23%
# processing permno 12463 / finished 17.29%
# processing permno 12465 / finished 17.34%
# processing permno 12469 / finished 17.39%
# processing permno 12470 / finished 17.45%
# processing permno 12471 / finished 17.50%
# processing permno 12472 / finished 17.56%
# processing permno 12473 / finished 17.61%
# processing permno 12476 / finished 17.66%
# processing permno 12477 / finished 17.72%
# processing permno 12478 / finished 17.77%
# processing permno 12480 / finished 17.82%
# processing permno 12481 / finished 17.88%
# processing permno 12486 / finished 17.93%
# processing permno 12487 / finished 17.99%
# processing permno 12488 / finished 18.04%
# processing permno 12489 / finished 18.09%
# processing permno 12490 / finished 18.15%
# processing permno 12492 / finished 18.20%
# processing permno 12493 / finished 18.26%
# processing permno 12494 / finished 18.31%
# processing permno 12495 / finished 18.36%
# processing permno 12496 / finished 18.42%
# processing permno 12497 / finished 18.47%
# processing permno 12498 / finished 18.52%
# processing permno 12500 / finished 18.58%
# processing permno 12501 / finished 18.63%
# processing permno 12502 / finished 18.69%
# processing permno 12503 / finished 18.74%
# processing permno 12505 / finished 18.79%
# processing permno 12508 / finished 18.85%
# processing permno 12509 / finished 18.90%
# processing permno 12510 / finished 18.96%
# processing permno 12513 / finished 19.01%
# processing permno 12514 / finished 19.06%
# processing permno 12515 / finished 19.12%
# processing permno 12516 / finished 19.17%
# processing permno 12521 / finished 19.22%
# processing permno 12523 / finished 19.28%
# processing permno 12527 / finished 19.33%
# processing permno 12528 / finished 19.39%
# processing permno 12530 / finished 19.44%
# processing permno 12531 / finished 19.49%
# processing permno 12533 / finished 19.55%
# processing permno 12534 / finished 19.60%
# processing permno 12535 / finished 19.66%
# processing permno 12536 / finished 19.71%
# processing permno 12537 / finished 19.76%
# processing permno 12540 / finished 19.82%
# processing permno 12541 / finished 19.87%
# processing permno 12542 / finished 19.92%
# processing permno 12543 / finished 19.98%
# processing permno 12552 / finished 20.03%
# processing permno 12553 / finished 20.09%
# processing permno 12556 / finished 20.14%
# processing permno 12557 / finished 20.19%
# processing permno 12558 / finished 20.25%
# processing permno 12559 / finished 20.30%
# processing permno 12560 / finished 20.36%
# processing permno 12561 / finished 20.41%
# processing permno 12564 / finished 20.46%
# processing permno 12565 / finished 20.52%
# processing permno 12566 / finished 20.57%
# processing permno 12569 / finished 20.62%
# processing permno 12570 / finished 20.68%
# processing permno 12573 / finished 20.73%
# processing permno 12575 / finished 20.79%
# processing permno 12577 / finished 20.84%
# processing permno 12578 / finished 20.89%
# processing permno 12579 / finished 20.95%
# processing permno 12582 / finished 21.00%
# processing permno 12583 / finished 21.06%
# processing permno 12584 / finished 21.11%
# processing permno 12585 / finished 21.16%
# processing permno 12587 / finished 21.22%
# processing permno 12588 / finished 21.27%
# processing permno 12591 / finished 21.32%
# processing permno 12592 / finished 21.38%
# processing permno 12593 / finished 21.43%
# processing permno 12594 / finished 21.49%
# processing permno 12595 / finished 21.54%
# processing permno 12596 / finished 21.59%
# processing permno 12615 / finished 21.65%
# processing permno 12621 / finished 21.70%
# processing permno 12622 / finished 21.76%
# processing permno 12623 / finished 21.81%
# processing permno 12624 / finished 21.86%
# processing permno 12625 / finished 21.92%
# processing permno 12628 / finished 21.97%
# processing permno 12629 / finished 22.02%
# processing permno 12631 / finished 22.08%
# processing permno 12632 / finished 22.13%
# processing permno 12633 / finished 22.19%
# processing permno 12636 / finished 22.24%
# processing permno 12637 / finished 22.29%
# processing permno 12638 / finished 22.35%
# processing permno 12639 / finished 22.40%
# processing permno 12640 / finished 22.46%
# processing permno 12641 / finished 22.51%
# processing permno 12644 / finished 22.56%
# processing permno 12645 / finished 22.62%
# processing permno 12646 / finished 22.67%
# processing permno 12647 / finished 22.72%
# processing permno 12648 / finished 22.78%
# processing permno 12649 / finished 22.83%
# processing permno 12650 / finished 22.89%
# processing permno 12651 / finished 22.94%
# processing permno 12652 / finished 22.99%
# processing permno 12653 / finished 23.05%
# processing permno 12654 / finished 23.10%
# processing permno 12655 / finished 23.16%
# processing permno 12656 / finished 23.21%
# processing permno 12657 / finished 23.26%
# processing permno 12658 / finished 23.32%
# processing permno 12659 / finished 23.37%
# processing permno 12660 / finished 23.42%
# processing permno 12662 / finished 23.48%
# processing permno 12665 / finished 23.53%
# processing permno 12666 / finished 23.59%
# processing permno 12667 / finished 23.64%
# processing permno 12668 / finished 23.69%
# processing permno 12671 / finished 23.75%
# processing permno 12672 / finished 23.80%
# processing permno 12673 / finished 23.86%
# processing permno 12674 / finished 23.91%
# processing permno 12675 / finished 23.96%
# processing permno 12676 / finished 24.02%
# processing permno 12679 / finished 24.07%
# processing permno 12680 / finished 24.12%
# processing permno 12681 / finished 24.18%
# processing permno 12683 / finished 24.23%
# processing permno 12684 / finished 24.29%
# processing permno 12689 / finished 24.34%
# processing permno 12690 / finished 24.39%
# processing permno 12693 / finished 24.45%
# processing permno 12695 / finished 24.50%
# processing permno 12696 / finished 24.56%
# processing permno 12697 / finished 24.61%
# processing permno 12698 / finished 24.66%
# processing permno 12699 / finished 24.72%
# processing permno 12717 / finished 24.77%
# processing permno 12720 / finished 24.82%
# processing permno 12727 / finished 24.88%
# processing permno 12728 / finished 24.93%
# processing permno 12729 / finished 24.99%
# processing permno 12732 / finished 25.04%
# processing permno 12738 / finished 25.09%
# processing permno 12739 / finished 25.15%
# processing permno 12740 / finished 25.20%
# processing permno 12741 / finished 25.26%
# processing permno 12742 / finished 25.31%
# processing permno 12744 / finished 25.36%
# processing permno 12745 / finished 25.42%
# processing permno 12746 / finished 25.47%
# processing permno 12747 / finished 25.53%
# processing permno 12748 / finished 25.58%
# processing permno 12751 / finished 25.63%
# processing permno 12753 / finished 25.69%
# processing permno 12754 / finished 25.74%
# processing permno 12756 / finished 25.79%
# processing permno 12758 / finished 25.85%
# processing permno 12759 / finished 25.90%
# processing permno 12781 / finished 25.96%
# processing permno 12783 / finished 26.01%
# processing permno 12785 / finished 26.06%
# processing permno 12786 / finished 26.12%
# processing permno 12788 / finished 26.17%
# processing permno 12789 / finished 26.23%
# processing permno 12791 / finished 26.28%
# processing permno 12792 / finished 26.33%
# processing permno 12795 / finished 26.39%
# processing permno 12796 / finished 26.44%
# processing permno 12797 / finished 26.49%
# processing permno 12798 / finished 26.55%
# processing permno 12799 / finished 26.60%
# processing permno 12826 / finished 26.66%
# processing permno 12828 / finished 26.71%
# processing permno 12831 / finished 26.76%
# processing permno 12832 / finished 26.82%
# processing permno 12833 / finished 26.87%
# processing permno 12834 / finished 26.93%
# processing permno 12835 / finished 26.98%
# processing permno 12839 / finished 27.03%
# processing permno 12840 / finished 27.09%
# processing permno 12841 / finished 27.14%
# processing permno 12842 / finished 27.19%
# processing permno 12843 / finished 27.25%
# processing permno 12844 / finished 27.30%
# processing permno 12847 / finished 27.36%
# processing permno 12850 / finished 27.41%
# processing permno 12852 / finished 27.46%
# processing permno 12867 / finished 27.52%
# processing permno 12868 / finished 27.57%
# processing permno 12870 / finished 27.63%
# processing permno 12871 / finished 27.68%
# processing permno 12872 / finished 27.73%
# processing permno 12873 / finished 27.79%
# processing permno 12874 / finished 27.84%
# processing permno 12875 / finished 27.89%
# processing permno 12876 / finished 27.95%
# processing permno 12877 / finished 28.00%
# processing permno 12878 / finished 28.06%
# processing permno 12880 / finished 28.11%
# processing permno 12881 / finished 28.16%
# processing permno 12884 / finished 28.22%
# processing permno 12885 / finished 28.27%
# processing permno 12886 / finished 28.33%
# processing permno 12890 / finished 28.38%
# processing permno 12891 / finished 28.43%
# processing permno 12892 / finished 28.49%
# processing permno 12893 / finished 28.54%
# processing permno 12894 / finished 28.59%
# processing permno 12895 / finished 28.65%
# processing permno 12899 / finished 28.70%
# processing permno 12901 / finished 28.76%
# processing permno 12902 / finished 28.81%
# processing permno 12904 / finished 28.86%
# processing permno 12905 / finished 28.92%
# processing permno 12906 / finished 28.97%
# processing permno 12908 / finished 29.03%
# processing permno 12911 / finished 29.08%
# processing permno 12912 / finished 29.13%
# processing permno 12913 / finished 29.19%
# processing permno 12914 / finished 29.24%
# processing permno 12915 / finished 29.29%
# processing permno 12916 / finished 29.35%
# processing permno 12919 / finished 29.40%
# processing permno 12920 / finished 29.46%
# processing permno 12922 / finished 29.51%
# processing permno 12923 / finished 29.56%
# processing permno 12924 / finished 29.62%
# processing permno 12927 / finished 29.67%
# processing permno 12928 / finished 29.73%
# processing permno 12946 / finished 29.78%
# processing permno 12947 / finished 29.83%
# processing permno 12948 / finished 29.89%
# processing permno 12949 / finished 29.94%
# processing permno 12952 / finished 29.99%
# processing permno 12953 / finished 30.05%
# processing permno 12954 / finished 30.10%
# processing permno 12957 / finished 30.16%
# processing permno 12960 / finished 30.21%
# processing permno 12961 / finished 30.26%
# processing permno 12963 / finished 30.32%
# processing permno 12965 / finished 30.37%
# processing permno 12971 / finished 30.43%
# processing permno 12972 / finished 30.48%
# processing permno 12974 / finished 30.53%
# processing permno 12975 / finished 30.59%
# processing permno 12978 / finished 30.64%
# processing permno 12979 / finished 30.69%
# processing permno 12980 / finished 30.75%
# processing permno 12981 / finished 30.80%
# processing permno 12982 / finished 30.86%
# processing permno 12983 / finished 30.91%
# processing permno 12986 / finished 30.96%
# processing permno 12988 / finished 31.02%
# processing permno 12991 / finished 31.07%
# processing permno 12994 / finished 31.13%
# processing permno 12995 / finished 31.18%
# processing permno 12996 / finished 31.23%
# processing permno 12997 / finished 31.29%
# processing permno 12998 / finished 31.34%
# processing permno 12999 / finished 31.39%
# processing permno 13000 / finished 31.45%
# processing permno 13001 / finished 31.50%
# processing permno 13002 / finished 31.56%
# processing permno 13003 / finished 31.61%
# processing permno 13006 / finished 31.66%
# processing permno 13007 / finished 31.72%
# processing permno 13008 / finished 31.77%
# processing permno 13009 / finished 31.83%
# processing permno 13013 / finished 31.88%
# processing permno 13014 / finished 31.93%
# processing permno 13015 / finished 31.99%
# processing permno 13016 / finished 32.04%
# processing permno 13017 / finished 32.09%
# processing permno 13019 / finished 32.15%
# processing permno 13022 / finished 32.20%
# processing permno 13023 / finished 32.26%
# processing permno 13024 / finished 32.31%
# processing permno 13025 / finished 32.36%
# processing permno 13026 / finished 32.42%
# processing permno 13027 / finished 32.47%
# processing permno 13029 / finished 32.53%
# processing permno 13030 / finished 32.58%
# processing permno 13031 / finished 32.63%
# processing permno 13032 / finished 32.69%
# processing permno 13033 / finished 32.74%
# processing permno 13034 / finished 32.79%
# processing permno 13035 / finished 32.85%
# processing permno 13036 / finished 32.90%
# processing permno 13037 / finished 32.96%
# processing permno 13038 / finished 33.01%
# processing permno 13041 / finished 33.06%
# processing permno 13046 / finished 33.12%
# processing permno 13049 / finished 33.17%
# processing permno 13076 / finished 33.23%
# processing permno 13077 / finished 33.28%
# processing permno 13079 / finished 33.33%
# processing permno 13080 / finished 33.39%
# processing permno 13081 / finished 33.44%
# processing permno 13082 / finished 33.49%
# processing permno 13084 / finished 33.55%
# processing permno 13085 / finished 33.60%
# processing permno 13089 / finished 33.66%
# processing permno 13090 / finished 33.71%
# processing permno 13091 / finished 33.76%
# processing permno 13092 / finished 33.82%
# processing permno 13093 / finished 33.87%
# processing permno 13097 / finished 33.93%
# processing permno 13102 / finished 33.98%
# processing permno 13103 / finished 34.03%
# processing permno 13104 / finished 34.09%
# processing permno 13105 / finished 34.14%
# processing permno 13106 / finished 34.19%
# processing permno 13107 / finished 34.25%
# processing permno 13108 / finished 34.30%
# processing permno 13109 / finished 34.36%
# processing permno 13110 / finished 34.41%
# processing permno 13111 / finished 34.46%
# processing permno 13112 / finished 34.52%
# processing permno 13113 / finished 34.57%
# processing permno 13114 / finished 34.63%
# processing permno 13116 / finished 34.68%
# processing permno 13117 / finished 34.73%
# processing permno 13121 / finished 34.79%
# processing permno 13122 / finished 34.84%
# processing permno 13124 / finished 34.89%
# processing permno 13126 / finished 34.95%
# processing permno 13129 / finished 35.00%
# processing permno 13130 / finished 35.06%
# processing permno 13131 / finished 35.11%
# processing permno 13132 / finished 35.16%
# processing permno 13133 / finished 35.22%
# processing permno 13134 / finished 35.27%
# processing permno 13137 / finished 35.33%
# processing permno 13138 / finished 35.38%
# processing permno 13139 / finished 35.43%
# processing permno 13140 / finished 35.49%
# processing permno 13141 / finished 35.54%
# processing permno 13142 / finished 35.60%
# processing permno 13145 / finished 35.65%
# processing permno 13159 / finished 35.70%
# processing permno 13160 / finished 35.76%
# processing permno 13161 / finished 35.81%
# processing permno 13162 / finished 35.86%
# processing permno 13163 / finished 35.92%
# processing permno 13167 / finished 35.97%
# processing permno 13168 / finished 36.03%
# processing permno 13169 / finished 36.08%
# processing permno 13172 / finished 36.13%
# processing permno 13174 / finished 36.19%
# processing permno 13176 / finished 36.24%
# processing permno 13180 / finished 36.30%
# processing permno 13181 / finished 36.35%
# processing permno 13182 / finished 36.40%
# processing permno 13185 / finished 36.46%
# processing permno 13188 / finished 36.51%
# processing permno 13189 / finished 36.56%
# processing permno 13190 / finished 36.62%
# processing permno 13191 / finished 36.67%
# processing permno 13193 / finished 36.73%
# processing permno 13195 / finished 36.78%
# processing permno 13196 / finished 36.83%
# processing permno 13198 / finished 36.89%
# processing permno 13200 / finished 36.94%
# processing permno 13201 / finished 37.00%
# processing permno 13202 / finished 37.05%
# processing permno 13203 / finished 37.10%
# processing permno 13204 / finished 37.16%
# processing permno 13206 / finished 37.21%
# processing permno 13208 / finished 37.26%
# processing permno 13209 / finished 37.32%
# processing permno 13210 / finished 37.37%
# processing permno 13211 / finished 37.43%
# processing permno 13212 / finished 37.48%
# processing permno 13213 / finished 37.53%
# processing permno 13214 / finished 37.59%
# processing permno 13217 / finished 37.64%
# processing permno 13218 / finished 37.70%
# processing permno 13219 / finished 37.75%
# processing permno 13220 / finished 37.80%
# processing permno 13221 / finished 37.86%
# processing permno 13226 / finished 37.91%
# processing permno 13228 / finished 37.96%
# processing permno 13229 / finished 38.02%
# processing permno 13230 / finished 38.07%
# processing permno 13233 / finished 38.13%
# processing permno 13234 / finished 38.18%
# processing permno 13235 / finished 38.23%
# processing permno 13236 / finished 38.29%
# processing permno 13240 / finished 38.34%
# processing permno 13241 / finished 38.40%
# processing permno 13242 / finished 38.45%
# processing permno 13243 / finished 38.50%
# processing permno 13244 / finished 38.56%
# processing permno 13245 / finished 38.61%
# processing permno 13246 / finished 38.66%
# processing permno 13249 / finished 38.72%
# processing permno 13251 / finished 38.77%
# processing permno 13252 / finished 38.83%
# processing permno 13253 / finished 38.88%
# processing permno 13254 / finished 38.93%
# processing permno 13255 / finished 38.99%
# processing permno 13260 / finished 39.04%
# processing permno 13261 / finished 39.10%
# processing permno 13262 / finished 39.15%
# processing permno 13263 / finished 39.20%
# processing permno 13264 / finished 39.26%
# processing permno 13265 / finished 39.31%
# processing permno 13267 / finished 39.36%
# processing permno 13268 / finished 39.42%
# processing permno 13273 / finished 39.47%
# processing permno 13278 / finished 39.53%
# processing permno 13279 / finished 39.58%
# processing permno 13280 / finished 39.63%
# processing permno 13284 / finished 39.69%
# processing permno 13286 / finished 39.74%
# processing permno 13287 / finished 39.80%
# processing permno 13288 / finished 39.85%
# processing permno 13289 / finished 39.90%
# processing permno 13292 / finished 39.96%
# processing permno 13293 / finished 40.01%
# processing permno 13295 / finished 40.06%
# processing permno 13296 / finished 40.12%
# processing permno 13297 / finished 40.17%
# processing permno 13299 / finished 40.23%
# processing permno 13300 / finished 40.28%
# processing permno 13301 / finished 40.33%
# processing permno 13302 / finished 40.39%
# processing permno 13303 / finished 40.44%
# processing permno 13305 / finished 40.50%
# processing permno 13308 / finished 40.55%
# processing permno 13309 / finished 40.60%
# processing permno 13310 / finished 40.66%
# processing permno 13314 / finished 40.71%
# processing permno 13315 / finished 40.76%
# processing permno 13316 / finished 40.82%
# processing permno 13317 / finished 40.87%
# processing permno 13318 / finished 40.93%
# processing permno 13319 / finished 40.98%
# processing permno 13321 / finished 41.03%
# processing permno 13322 / finished 41.09%
# processing permno 13323 / finished 41.14%
# processing permno 13324 / finished 41.20%
# processing permno 13325 / finished 41.25%
# processing permno 13326 / finished 41.30%
# processing permno 13327 / finished 41.36%
# processing permno 13328 / finished 41.41%
# processing permno 13329 / finished 41.46%
# processing permno 13330 / finished 41.52%
# processing permno 13332 / finished 41.57%
# processing permno 13333 / finished 41.63%
# processing permno 13334 / finished 41.68%
# processing permno 13335 / finished 41.73%
# processing permno 13337 / finished 41.79%
# processing permno 13340 / finished 41.84%
# processing permno 13341 / finished 41.90%
# processing permno 13342 / finished 41.95%
# processing permno 13343 / finished 42.00%
# processing permno 13344 / finished 42.06%
# processing permno 13345 / finished 42.11%
# processing permno 13348 / finished 42.16%
# processing permno 13349 / finished 42.22%
# processing permno 13350 / finished 42.27%
# processing permno 13351 / finished 42.33%
# processing permno 13352 / finished 42.38%
# processing permno 13353 / finished 42.43%
# processing permno 13356 / finished 42.49%
# processing permno 13357 / finished 42.54%
# processing permno 13358 / finished 42.60%
# processing permno 13360 / finished 42.65%
# processing permno 13361 / finished 42.70%
# processing permno 13364 / finished 42.76%
# processing permno 13365 / finished 42.81%
# processing permno 13366 / finished 42.86%
# processing permno 13367 / finished 42.92%
# processing permno 13368 / finished 42.97%
# processing permno 13369 / finished 43.03%
# processing permno 13373 / finished 43.08%
# processing permno 13375 / finished 43.13%
# processing permno 13376 / finished 43.19%
# processing permno 13377 / finished 43.24%
# processing permno 13379 / finished 43.30%
# processing permno 13380 / finished 43.35%
# processing permno 13381 / finished 43.40%
# processing permno 13382 / finished 43.46%
# processing permno 13384 / finished 43.51%
# processing permno 13385 / finished 43.56%
# processing permno 13386 / finished 43.62%
# processing permno 13387 / finished 43.67%
# processing permno 13388 / finished 43.73%
# processing permno 13392 / finished 43.78%
# processing permno 13393 / finished 43.83%
# processing permno 13394 / finished 43.89%
# processing permno 13395 / finished 43.94%
# processing permno 13396 / finished 44.00%
# processing permno 13399 / finished 44.05%
# processing permno 13400 / finished 44.10%
# processing permno 13401 / finished 44.16%
# processing permno 13403 / finished 44.21%
# processing permno 13405 / finished 44.26%
# processing permno 13407 / finished 44.32%
# processing permno 13408 / finished 44.37%
# processing permno 13409 / finished 44.43%
# processing permno 13410 / finished 44.48%
# processing permno 13411 / finished 44.53%
# processing permno 13412 / finished 44.59%
# processing permno 13425 / finished 44.64%
# processing permno 13428 / finished 44.70%
# processing permno 13429 / finished 44.75%
# processing permno 13431 / finished 44.80%
# processing permno 13432 / finished 44.86%
# processing permno 13433 / finished 44.91%
# processing permno 13436 / finished 44.96%
# processing permno 13437 / finished 45.02%
# processing permno 13438 / finished 45.07%
# processing permno 13439 / finished 45.13%
# processing permno 13440 / finished 45.18%
# processing permno 13441 / finished 45.23%
# processing permno 13444 / finished 45.29%
# processing permno 13445 / finished 45.34%
# processing permno 13446 / finished 45.40%
# processing permno 13447 / finished 45.45%
# processing permno 13452 / finished 45.50%
# processing permno 13453 / finished 45.56%
# processing permno 13454 / finished 45.61%
# processing permno 13455 / finished 45.67%
# processing permno 13456 / finished 45.72%
# processing permno 13499 / finished 45.77%
# processing permno 13501 / finished 45.83%
# processing permno 13502 / finished 45.88%
# processing permno 13503 / finished 45.93%
# processing permno 13504 / finished 45.99%
# processing permno 13505 / finished 46.04%
# processing permno 13507 / finished 46.10%
# processing permno 13508 / finished 46.15%
# processing permno 13509 / finished 46.20%
# processing permno 13510 / finished 46.26%
# processing permno 13511 / finished 46.31%
# processing permno 13512 / finished 46.37%
# processing permno 13513 / finished 46.42%
# processing permno 13517 / finished 46.47%
# processing permno 13518 / finished 46.53%
# processing permno 13519 / finished 46.58%
# processing permno 13520 / finished 46.63%
# processing permno 13521 / finished 46.69%
# processing permno 13524 / finished 46.74%
# processing permno 13527 / finished 46.80%
# processing permno 13528 / finished 46.85%
# processing permno 13529 / finished 46.90%
# processing permno 13532 / finished 46.96%
# processing permno 13534 / finished 47.01%
# processing permno 13537 / finished 47.07%
# processing permno 13538 / finished 47.12%
# processing permno 13539 / finished 47.17%
# processing permno 13540 / finished 47.23%
# processing permno 13541 / finished 47.28%
# processing permno 13542 / finished 47.33%
# processing permno 13543 / finished 47.39%
# processing permno 13544 / finished 47.44%
# processing permno 13545 / finished 47.50%
# processing permno 13547 / finished 47.55%
# processing permno 13548 / finished 47.60%
# processing permno 13553 / finished 47.66%
# processing permno 13554 / finished 47.71%
# processing permno 13555 / finished 47.77%
# processing permno 13556 / finished 47.82%
# processing permno 13559 / finished 47.87%
# processing permno 13561 / finished 47.93%
# processing permno 13562 / finished 47.98%
# processing permno 13563 / finished 48.03%
# processing permno 13564 / finished 48.09%
# processing permno 13567 / finished 48.14%
# processing permno 13568 / finished 48.20%
# processing permno 13569 / finished 48.25%
# processing permno 13570 / finished 48.30%
# processing permno 13571 / finished 48.36%
# processing permno 13572 / finished 48.41%
# processing permno 13575 / finished 48.47%
# processing permno 13576 / finished 48.52%
# processing permno 13577 / finished 48.57%
# processing permno 13578 / finished 48.63%
# processing permno 13579 / finished 48.68%
# processing permno 13583 / finished 48.73%
# processing permno 13584 / finished 48.79%
# processing permno 13586 / finished 48.84%
# processing permno 13594 / finished 48.90%
# processing permno 13595 / finished 48.95%
# processing permno 13597 / finished 49.00%
# processing permno 13599 / finished 49.06%
# processing permno 13600 / finished 49.11%
# processing permno 13601 / finished 49.17%
# processing permno 13604 / finished 49.22%
# processing permno 13605 / finished 49.27%
# processing permno 13606 / finished 49.33%
# processing permno 13607 / finished 49.38%
# processing permno 13608 / finished 49.43%
# processing permno 13609 / finished 49.49%
# processing permno 13610 / finished 49.54%
# processing permno 13612 / finished 49.60%
# processing permno 13613 / finished 49.65%
# processing permno 13614 / finished 49.70%
# processing permno 13615 / finished 49.76%
# processing permno 13616 / finished 49.81%
# processing permno 13617 / finished 49.87%
# processing permno 13618 / finished 49.92%
# processing permno 13619 / finished 49.97%
# processing permno 13620 / finished 50.03%
# processing permno 13621 / finished 50.08%
# processing permno 13622 / finished 50.13%
# processing permno 13623 / finished 50.19%
# processing permno 13624 / finished 50.24%
# processing permno 13625 / finished 50.30%
# processing permno 13626 / finished 50.35%
# processing permno 13627 / finished 50.40%
# processing permno 13628 / finished 50.46%
# processing permno 13631 / finished 50.51%
# processing permno 13632 / finished 50.57%
# processing permno 13633 / finished 50.62%
# processing permno 13634 / finished 50.67%
# processing permno 13636 / finished 50.73%
# processing permno 13640 / finished 50.78%
# processing permno 13641 / finished 50.83%
# processing permno 13642 / finished 50.89%
# processing permno 13643 / finished 50.94%
# processing permno 13647 / finished 51.00%
# processing permno 13648 / finished 51.05%
# processing permno 13650 / finished 51.10%
# processing permno 13652 / finished 51.16%
# processing permno 13655 / finished 51.21%
# processing permno 13656 / finished 51.27%
# processing permno 13657 / finished 51.32%
# processing permno 13658 / finished 51.37%
# processing permno 13678 / finished 51.43%
# processing permno 13679 / finished 51.48%
# processing permno 13680 / finished 51.53%
# processing permno 13681 / finished 51.59%
# processing permno 13684 / finished 51.64%
# processing permno 13685 / finished 51.70%
# processing permno 13686 / finished 51.75%
# processing permno 13687 / finished 51.80%
# processing permno 13688 / finished 51.86%
# processing permno 13690 / finished 51.91%
# processing permno 13691 / finished 51.97%
# processing permno 13692 / finished 52.02%
# processing permno 13693 / finished 52.07%
# processing permno 13694 / finished 52.13%
# processing permno 13695 / finished 52.18%
# processing permno 13698 / finished 52.23%
# processing permno 13700 / finished 52.29%
# processing permno 13701 / finished 52.34%
# processing permno 13702 / finished 52.40%
# processing permno 13704 / finished 52.45%
# processing permno 13705 / finished 52.50%
# processing permno 13706 / finished 52.56%
# processing permno 13707 / finished 52.61%
# processing permno 13711 / finished 52.67%
# processing permno 13712 / finished 52.72%
# processing permno 13713 / finished 52.77%
# processing permno 13714 / finished 52.83%
# processing permno 13721 / finished 52.88%
# processing permno 13723 / finished 52.93%
# processing permno 13724 / finished 52.99%
# processing permno 13727 / finished 53.04%
# processing permno 13728 / finished 53.10%
# processing permno 13729 / finished 53.15%
# processing permno 13730 / finished 53.20%
# processing permno 13731 / finished 53.26%
# processing permno 13732 / finished 53.31%
# processing permno 13736 / finished 53.37%
# processing permno 13737 / finished 53.42%
# processing permno 13738 / finished 53.47%
# processing permno 13739 / finished 53.53%
# processing permno 13740 / finished 53.58%
# processing permno 13743 / finished 53.63%
# processing permno 13744 / finished 53.69%
# processing permno 13745 / finished 53.74%
# processing permno 13746 / finished 53.80%
# processing permno 13747 / finished 53.85%
# processing permno 13748 / finished 53.90%
# processing permno 13749 / finished 53.96%
# processing permno 13750 / finished 54.01%
# processing permno 13751 / finished 54.07%
# processing permno 13752 / finished 54.12%
# processing permno 13753 / finished 54.17%
# processing permno 13755 / finished 54.23%
# processing permno 13756 / finished 54.28%
# processing permno 13757 / finished 54.33%
# processing permno 13758 / finished 54.39%
# processing permno 13760 / finished 54.44%
# processing permno 13761 / finished 54.50%
# processing permno 13762 / finished 54.55%
# processing permno 13763 / finished 54.60%
# processing permno 13764 / finished 54.66%
# processing permno 13765 / finished 54.71%
# processing permno 13766 / finished 54.77%
# processing permno 13767 / finished 54.82%
# processing permno 13769 / finished 54.87%
# processing permno 13770 / finished 54.93%
# processing permno 13771 / finished 54.98%
# processing permno 13772 / finished 55.04%
# processing permno 13774 / finished 55.09%
# processing permno 13775 / finished 55.14%
# processing permno 13777 / finished 55.20%
# processing permno 13779 / finished 55.25%
# processing permno 13780 / finished 55.30%
# processing permno 13781 / finished 55.36%
# processing permno 13782 / finished 55.41%
# processing permno 13783 / finished 55.47%
# processing permno 13786 / finished 55.52%
# processing permno 13787 / finished 55.57%
# processing permno 13788 / finished 55.63%
# processing permno 13789 / finished 55.68%
# processing permno 13794 / finished 55.74%
# processing permno 13795 / finished 55.79%
# processing permno 13796 / finished 55.84%
# processing permno 13797 / finished 55.90%
# processing permno 13798 / finished 55.95%
# processing permno 13799 / finished 56.00%
# processing permno 13801 / finished 56.06%
# processing permno 13802 / finished 56.11%
# processing permno 13804 / finished 56.17%
# processing permno 13807 / finished 56.22%
# processing permno 13808 / finished 56.27%
# processing permno 13809 / finished 56.33%
# processing permno 13810 / finished 56.38%
# processing permno 13811 / finished 56.44%
# processing permno 13812 / finished 56.49%
# processing permno 13815 / finished 56.54%
# processing permno 13816 / finished 56.60%
# processing permno 13817 / finished 56.65%
# processing permno 13818 / finished 56.70%
# processing permno 13819 / finished 56.76%
# processing permno 13820 / finished 56.81%
# processing permno 13823 / finished 56.87%
# processing permno 13825 / finished 56.92%
# processing permno 13826 / finished 56.97%
# processing permno 13827 / finished 57.03%
# processing permno 13828 / finished 57.08%
# processing permno 13829 / finished 57.14%
# processing permno 13830 / finished 57.19%
# processing permno 13831 / finished 57.24%
# processing permno 13833 / finished 57.30%
# processing permno 13834 / finished 57.35%
# processing permno 13835 / finished 57.40%
# processing permno 13836 / finished 57.46%
# processing permno 13837 / finished 57.51%
# processing permno 13838 / finished 57.57%
# processing permno 13839 / finished 57.62%
# processing permno 13840 / finished 57.67%
# processing permno 13842 / finished 57.73%
# processing permno 13843 / finished 57.78%
# processing permno 13844 / finished 57.84%
# processing permno 13845 / finished 57.89%
# processing permno 13846 / finished 57.94%
# processing permno 13847 / finished 58.00%
# processing permno 13850 / finished 58.05%
# processing permno 13851 / finished 58.10%
# processing permno 13852 / finished 58.16%
# processing permno 13853 / finished 58.21%
# processing permno 13854 / finished 58.27%
# processing permno 13855 / finished 58.32%
# processing permno 13856 / finished 58.37%
# processing permno 13859 / finished 58.43%
# processing permno 13860 / finished 58.48%
# processing permno 13862 / finished 58.54%
# processing permno 13863 / finished 58.59%
# processing permno 13866 / finished 58.64%
# processing permno 13867 / finished 58.70%
# processing permno 13869 / finished 58.75%
# processing permno 13870 / finished 58.80%
# processing permno 13874 / finished 58.86%
# processing permno 13875 / finished 58.91%
# processing permno 13876 / finished 58.97%
# processing permno 13877 / finished 59.02%
# processing permno 13878 / finished 59.07%
# processing permno 13879 / finished 59.13%
# processing permno 13883 / finished 59.18%
# processing permno 13885 / finished 59.24%
# processing permno 13886 / finished 59.29%
# processing permno 13887 / finished 59.34%
# processing permno 13888 / finished 59.40%
# processing permno 13889 / finished 59.45%
# processing permno 13890 / finished 59.50%
# processing permno 13894 / finished 59.56%
# processing permno 13895 / finished 59.61%
# processing permno 13896 / finished 59.67%
# processing permno 13897 / finished 59.72%
# processing permno 13898 / finished 59.77%
# processing permno 13901 / finished 59.83%
# processing permno 13903 / finished 59.88%
# processing permno 13904 / finished 59.94%
# processing permno 13905 / finished 59.99%
# processing permno 13906 / finished 60.04%
# processing permno 13907 / finished 60.10%
# processing permno 13908 / finished 60.15%
# processing permno 13909 / finished 60.20%
# processing permno 13910 / finished 60.26%
# processing permno 13911 / finished 60.31%
# processing permno 13912 / finished 60.37%
# processing permno 13913 / finished 60.42%
# processing permno 13914 / finished 60.47%
# processing permno 13915 / finished 60.53%
# processing permno 13917 / finished 60.58%
# processing permno 13918 / finished 60.64%
# processing permno 13919 / finished 60.69%
# processing permno 13921 / finished 60.74%
# processing permno 13922 / finished 60.80%
# processing permno 13923 / finished 60.85%
# processing permno 13924 / finished 60.90%
# processing permno 13925 / finished 60.96%
# processing permno 13926 / finished 61.01%
# processing permno 13927 / finished 61.07%
# processing permno 13928 / finished 61.12%
# processing permno 13930 / finished 61.17%
# processing permno 13931 / finished 61.23%
# processing permno 13932 / finished 61.28%
# ...
# processing permno 92810 / finished 79.59%
# processing permno 92812 / finished 79.64%
# processing permno 92813 / finished 79.70%
# processing permno 92814 / finished 79.75%
# processing permno 92816 / finished 79.81%
# processing permno 92817 / finished 79.86%
# processing permno 92818 / finished 79.91%
# processing permno 92819 / finished 79.97%
# processing permno 92820 / finished 80.02%
# processing permno 92822 / finished 80.08%
# processing permno 92824 / finished 80.13%
# processing permno 92834 / finished 80.18%
# processing permno 92835 / finished 80.24%
# processing permno 92836 / finished 80.29%
# processing permno 92837 / finished 80.34%
# processing permno 92839 / finished 80.40%
# processing permno 92840 / finished 80.45%
# processing permno 92841 / finished 80.51%
# processing permno 92842 / finished 80.56%
# processing permno 92843 / finished 80.61%
# processing permno 92844 / finished 80.67%
# processing permno 92845 / finished 80.72%
# processing permno 92846 / finished 80.78%
# processing permno 92847 / finished 80.83%
# processing permno 92848 / finished 80.88%
# processing permno 92849 / finished 80.94%
# processing permno 92852 / finished 80.99%
# processing permno 92854 / finished 81.04%
# processing permno 92855 / finished 81.10%
# processing permno 92856 / finished 81.15%
# processing permno 92857 / finished 81.21%
# processing permno 92858 / finished 81.26%
# processing permno 92859 / finished 81.31%
# processing permno 92860 / finished 81.37%
# processing permno 92862 / finished 81.42%
# processing permno 92863 / finished 81.48%
# processing permno 92864 / finished 81.53%
# processing permno 92865 / finished 81.58%
# processing permno 92870 / finished 81.64%
# processing permno 92871 / finished 81.69%
# processing permno 92872 / finished 81.74%
# processing permno 92873 / finished 81.80%
# processing permno 92876 / finished 81.85%
# processing permno 92877 / finished 81.91%
# processing permno 92878 / finished 81.96%
# processing permno 92880 / finished 82.01%
# processing permno 92881 / finished 82.07%
# processing permno 92883 / finished 82.12%
# processing permno 92884 / finished 82.18%
# processing permno 92885 / finished 82.23%
# processing permno 92886 / finished 82.28%
# processing permno 92887 / finished 82.34%
# processing permno 92888 / finished 82.39%
# processing permno 92889 / finished 82.44%
# processing permno 92890 / finished 82.50%
# processing permno 92891 / finished 82.55%
# processing permno 92892 / finished 82.61%
# processing permno 92893 / finished 82.66%
# processing permno 92894 / finished 82.71%
# processing permno 92897 / finished 82.77%
# processing permno 92898 / finished 82.82%
# processing permno 92900 / finished 82.88%
# processing permno 92901 / finished 82.93%
# processing permno 92902 / finished 82.98%
# processing permno 92904 / finished 83.04%
# processing permno 92905 / finished 83.09%
# processing permno 92906 / finished 83.14%
# processing permno 92907 / finished 83.20%
# processing permno 92908 / finished 83.25%
# processing permno 92909 / finished 83.31%
# processing permno 92910 / finished 83.36%
# processing permno 92912 / finished 83.41%
# processing permno 92913 / finished 83.47%
# processing permno 92914 / finished 83.52%
# processing permno 92916 / finished 83.58%
# processing permno 92917 / finished 83.63%
# processing permno 92918 / finished 83.68%
# processing permno 92919 / finished 83.74%
# processing permno 92922 / finished 83.79%
# processing permno 92924 / finished 83.84%
# processing permno 92927 / finished 83.90%
# processing permno 92928 / finished 83.95%
# processing permno 92929 / finished 84.01%
# processing permno 92931 / finished 84.06%
# processing permno 92933 / finished 84.11%
# processing permno 92935 / finished 84.17%
# processing permno 92936 / finished 84.22%
# processing permno 92939 / finished 84.28%
# processing permno 92940 / finished 84.33%
# processing permno 92945 / finished 84.38%
# processing permno 92948 / finished 84.44%
# processing permno 92949 / finished 84.49%
# processing permno 92950 / finished 84.54%
# processing permno 92951 / finished 84.60%
# processing permno 92952 / finished 84.65%
# processing permno 92953 / finished 84.71%
# processing permno 92955 / finished 84.76%
# processing permno 92956 / finished 84.81%
# processing permno 92957 / finished 84.87%
# processing permno 92958 / finished 84.92%
# processing permno 92959 / finished 84.98%
# processing permno 92960 / finished 85.03%
# processing permno 92961 / finished 85.08%
# processing permno 92963 / finished 85.14%
# processing permno 92964 / finished 85.19%
# processing permno 92966 / finished 85.25%
# processing permno 92967 / finished 85.30%
# processing permno 92968 / finished 85.35%
# processing permno 92969 / finished 85.41%
# processing permno 92971 / finished 85.46%
# processing permno 92972 / finished 85.51%
# processing permno 92974 / finished 85.57%
# processing permno 92976 / finished 85.62%
# processing permno 92977 / finished 85.68%
# processing permno 92980 / finished 85.73%
# processing permno 92981 / finished 85.78%
# processing permno 92984 / finished 85.84%
# processing permno 92985 / finished 85.89%
# processing permno 92986 / finished 85.95%
# processing permno 92987 / finished 86.00%
# processing permno 92993 / finished 86.05%
# processing permno 92994 / finished 86.11%
# processing permno 92995 / finished 86.16%
# processing permno 92996 / finished 86.21%
# processing permno 92999 / finished 86.27%
# processing permno 93001 / finished 86.32%
# processing permno 93002 / finished 86.38%
# processing permno 93004 / finished 86.43%
# processing permno 93010 / finished 86.48%
# processing permno 93012 / finished 86.54%
# processing permno 93013 / finished 86.59%
# processing permno 93014 / finished 86.65%
# processing permno 93016 / finished 86.70%
# processing permno 93018 / finished 86.75%
# processing permno 93021 / finished 86.81%
# processing permno 93022 / finished 86.86%
# processing permno 93023 / finished 86.91%
# processing permno 93024 / finished 86.97%
# processing permno 93026 / finished 87.02%
# processing permno 93027 / finished 87.08%
# processing permno 93028 / finished 87.13%
# processing permno 93031 / finished 87.18%
# processing permno 93032 / finished 87.24%
# processing permno 93035 / finished 87.29%
# processing permno 93036 / finished 87.35%
# processing permno 93052 / finished 87.40%
# processing permno 93053 / finished 87.45%
# processing permno 93054 / finished 87.51%
# processing permno 93055 / finished 87.56%
# processing permno 93057 / finished 87.61%
# processing permno 93058 / finished 87.67%
# processing permno 93062 / finished 87.72%
# processing permno 93063 / finished 87.78%
# processing permno 93065 / finished 87.83%
# processing permno 93067 / finished 87.88%
# processing permno 93069 / finished 87.94%
# processing permno 93070 / finished 87.99%
# processing permno 93071 / finished 88.05%
# processing permno 93073 / finished 88.10%
# processing permno 93078 / finished 88.15%
# processing permno 93079 / finished 88.21%
# processing permno 93082 / finished 88.26%
# processing permno 93083 / finished 88.31%
# processing permno 93085 / finished 88.37%
# processing permno 93087 / finished 88.42%
# processing permno 93089 / finished 88.48%
# processing permno 93093 / finished 88.53%
# processing permno 93094 / finished 88.58%
# processing permno 93095 / finished 88.64%
# processing permno 93096 / finished 88.69%
# processing permno 93098 / finished 88.75%
# processing permno 93099 / finished 88.80%
# processing permno 93101 / finished 88.85%
# processing permno 93102 / finished 88.91%
# processing permno 93103 / finished 88.96%
# processing permno 93104 / finished 89.01%
# processing permno 93106 / finished 89.07%
# processing permno 93108 / finished 89.12%
# processing permno 93109 / finished 89.18%
# processing permno 93110 / finished 89.23%
# processing permno 93112 / finished 89.28%
# processing permno 93114 / finished 89.34%
# processing permno 93115 / finished 89.39%
# processing permno 93116 / finished 89.45%
# processing permno 93117 / finished 89.50%
# processing permno 93120 / finished 89.55%
# processing permno 93122 / finished 89.61%
# processing permno 93123 / finished 89.66%
# processing permno 93126 / finished 89.71%
# processing permno 93128 / finished 89.77%
# processing permno 93130 / finished 89.82%
# processing permno 93131 / finished 89.88%
# processing permno 93132 / finished 89.93%
# processing permno 93134 / finished 89.98%
# processing permno 93137 / finished 90.04%
# processing permno 93142 / finished 90.09%
# processing permno 93143 / finished 90.15%
# processing permno 93144 / finished 90.20%
# processing permno 93145 / finished 90.25%
# processing permno 93146 / finished 90.31%
# processing permno 93147 / finished 90.36%
# processing permno 93148 / finished 90.41%
# processing permno 93149 / finished 90.47%
# processing permno 93150 / finished 90.52%
# processing permno 93151 / finished 90.58%
# processing permno 93152 / finished 90.63%
# processing permno 93153 / finished 90.68%
# processing permno 93155 / finished 90.74%
# processing permno 93157 / finished 90.79%
# processing permno 93158 / finished 90.85%
# processing permno 93159 / finished 90.90%
# processing permno 93166 / finished 90.95%
# processing permno 93167 / finished 91.01%
# processing permno 93168 / finished 91.06%
# processing permno 93169 / finished 91.11%
# processing permno 93170 / finished 91.17%
# processing permno 93171 / finished 91.22%
# processing permno 93173 / finished 91.28%
# processing permno 93174 / finished 91.33%
# processing permno 93175 / finished 91.38%
# processing permno 93177 / finished 91.44%
# processing permno 93178 / finished 91.49%
# processing permno 93179 / finished 91.55%
# processing permno 93180 / finished 91.60%
# processing permno 93181 / finished 91.65%
# processing permno 93182 / finished 91.71%
# processing permno 93183 / finished 91.76%
# processing permno 93185 / finished 91.81%
# processing permno 93186 / finished 91.87%
# processing permno 93187 / finished 91.92%
# processing permno 93188 / finished 91.98%
# processing permno 93189 / finished 92.03%
# processing permno 93190 / finished 92.08%
# processing permno 93191 / finished 92.14%
# processing permno 93200 / finished 92.19%
# processing permno 93203 / finished 92.25%
# processing permno 93204 / finished 92.30%
# processing permno 93206 / finished 92.35%
# processing permno 93207 / finished 92.41%
# processing permno 93208 / finished 92.46%
# processing permno 93210 / finished 92.51%
# processing permno 93211 / finished 92.57%
# processing permno 93212 / finished 92.62%
# processing permno 93217 / finished 92.68%
# processing permno 93218 / finished 92.73%
# processing permno 93219 / finished 92.78%
# processing permno 93221 / finished 92.84%
# processing permno 93222 / finished 92.89%
# processing permno 93223 / finished 92.95%
# processing permno 93231 / finished 93.00%
# processing permno 93233 / finished 93.05%
# processing permno 93237 / finished 93.11%
# processing permno 93239 / finished 93.16%
# processing permno 93246 / finished 93.21%
# processing permno 93248 / finished 93.27%
# processing permno 93249 / finished 93.32%
# processing permno 93251 / finished 93.38%
# processing permno 93253 / finished 93.43%
# processing permno 93254 / finished 93.48%
# processing permno 93255 / finished 93.54%
# processing permno 93256 / finished 93.59%
# processing permno 93257 / finished 93.65%
# processing permno 93258 / finished 93.70%
# processing permno 93259 / finished 93.75%
# processing permno 93260 / finished 93.81%
# processing permno 93261 / finished 93.86%
# processing permno 93262 / finished 93.91%
# processing permno 93263 / finished 93.97%
# processing permno 93264 / finished 94.02%
# processing permno 93266 / finished 94.08%
# processing permno 93267 / finished 94.13%
# processing permno 93268 / finished 94.18%
# processing permno 93269 / finished 94.24%
# processing permno 93270 / finished 94.29%
# processing permno 93272 / finished 94.35%
# processing permno 93274 / finished 94.40%
# processing permno 93275 / finished 94.45%
# processing permno 93282 / finished 94.51%
# processing permno 93283 / finished 94.56%
# processing permno 93284 / finished 94.61%
# processing permno 93285 / finished 94.67%
# processing permno 93286 / finished 94.72%
# processing permno 93288 / finished 94.78%
# processing permno 93289 / finished 94.83%
# processing permno 93291 / finished 94.88%
# processing permno 93292 / finished 94.94%
# processing permno 93293 / finished 94.99%
# processing permno 93294 / finished 95.05%
# processing permno 93295 / finished 95.10%
# processing permno 93296 / finished 95.15%
# processing permno 93299 / finished 95.21%
# processing permno 93300 / finished 95.26%
# processing permno 93301 / finished 95.32%
# processing permno 93302 / finished 95.37%
# processing permno 93303 / finished 95.42%
# processing permno 93304 / finished 95.48%
# processing permno 93305 / finished 95.53%
# processing permno 93306 / finished 95.58%
# processing permno 93309 / finished 95.64%
# processing permno 93312 / finished 95.69%
# processing permno 93313 / finished 95.75%
# processing permno 93314 / finished 95.80%
# processing permno 93318 / finished 95.85%
# processing permno 93319 / finished 95.91%
# processing permno 93325 / finished 95.96%
# processing permno 93330 / finished 96.02%
# processing permno 93331 / finished 96.07%
# processing permno 93332 / finished 96.12%
# processing permno 93333 / finished 96.18%
# processing permno 93334 / finished 96.23%
# processing permno 93335 / finished 96.28%
# processing permno 93336 / finished 96.34%
# processing permno 93337 / finished 96.39%
# processing permno 93338 / finished 96.45%
# processing permno 93339 / finished 96.50%
# processing permno 93340 / finished 96.55%
# processing permno 93341 / finished 96.61%
# processing permno 93342 / finished 96.66%
# processing permno 93343 / finished 96.72%
# processing permno 93344 / finished 96.77%
# processing permno 93345 / finished 96.82%
# processing permno 93347 / finished 96.88%
# processing permno 93350 / finished 96.93%
# processing permno 93352 / finished 96.98%
# processing permno 93354 / finished 97.04%
# processing permno 93356 / finished 97.09%
# processing permno 93357 / finished 97.15%
# processing permno 93359 / finished 97.20%
# processing permno 93360 / finished 97.25%
# processing permno 93361 / finished 97.31%
# processing permno 93362 / finished 97.36%
# processing permno 93363 / finished 97.42%
# processing permno 93364 / finished 97.47%
# processing permno 93365 / finished 97.52%
# processing permno 93366 / finished 97.58%
# processing permno 93367 / finished 97.63%
# processing permno 93368 / finished 97.68%
# processing permno 93369 / finished 97.74%
# processing permno 93370 / finished 97.79%
# processing permno 93371 / finished 97.85%
# processing permno 93372 / finished 97.90%
# processing permno 93373 / finished 97.95%
# processing permno 93374 / finished 98.01%
# processing permno 93376 / finished 98.06%
# processing permno 93377 / finished 98.12%
# processing permno 93378 / finished 98.17%
# processing permno 93379 / finished 98.22%
# processing permno 93380 / finished 98.28%
# processing permno 93381 / finished 98.33%
# processing permno 93384 / finished 98.38%
# processing permno 93385 / finished 98.44%
# processing permno 93386 / finished 98.49%
# processing permno 93393 / finished 98.55%
# processing permno 93396 / finished 98.60%
# processing permno 93397 / finished 98.65%
# processing permno 93399 / finished 98.71%
# processing permno 93400 / finished 98.76%
# processing permno 93401 / finished 98.82%
# processing permno 93406 / finished 98.87%
# processing permno 93407 / finished 98.92%
# processing permno 93408 / finished 98.98%
# processing permno 93414 / finished 99.03%
# processing permno 93415 / finished 99.08%
# processing permno 93416 / finished 99.14%
# processing permno 93417 / finished 99.19%
# processing permno 93418 / finished 99.25%
# processing permno 93419 / finished 99.30%
# processing permno 93420 / finished 99.35%
# processing permno 93421 / finished 99.41%
# processing permno 93422 / finished 99.46%
# processing permno 93423 / finished 99.52%
# processing permno 93424 / finished 99.57%
# processing permno 93425 / finished 99.62%
# processing permno 93426 / finished 99.68%
# processing permno 93427 / finished 99.73%
# processing permno 93428 / finished 99.78%
# processing permno 93429 / finished 99.84%
# processing permno 93433 / finished 99.89%
# processing permno 93434 / finished 99.95%
# processing permno 93436 / finished 100.00%

# %%
# process dataframe
crsp = crsp.dropna(subset=['beta'])  # drop NA due to rolling
crsp = crsp.reset_index(drop=True)
crsp = crsp[['permno', 'date', 'beta']]
crsp.to_feather('processed_data/beta.ftr')
