# %%
# Fama & French 3 factors residual variance
# Note: Please use the latest version of pandas, this version should support returning to pd.Series after rolling
# To get a faster speed, we split the big dataframe into small ones
# Then using different process to calculate the variance
# We use 20 process to calculate variance, you can change the number of process according to your CPU situation
# You can use the following code to check your CPU situation
# import multiprocessing
# multiprocessing.cpu_count()

import pandas as pd
import numpy as np
import datetime as dt
import wrds
from dateutil.relativedelta import *
from pandas.tseries.offsets import *
import datetime
import pickle as pkl
import pyarrow.feather as feather
import multiprocessing as mp
import os
# Out:
# WRDS recommends setting up a .pgpass file.
# Created .pgpass file successfully.
# You can create this file yourself at any time with the create_pgpass_file() function.
# Loading library list...
# Done

# %%
crsp = pd.read_feather("raw_data/ill_crsp.ftr")

# %%
# sort variables by permno and date
crsp = crsp.sort_values(by=['permno', 'date'])

# change variable format to int
crsp['permno'] = crsp['permno'].astype(int)

# Line up date to be end of month
crsp['date'] = pd.to_datetime(crsp['date'])

# add delisting return
dlret = pd.read_feather("raw_data/dlret.ftr")

dlret.permno = dlret.permno.astype(int)
dlret['dlstdt'] = pd.to_datetime(dlret['dlstdt'])
dlret['date'] = dlret['dlstdt']

# merge delisting return to crsp return
crsp = pd.merge(crsp, dlret, how='left', on=['permno', 'date'])
crsp['dlret'] = crsp['dlret'].fillna(0)
crsp['ret'] = crsp['ret'].fillna(0)
crsp['retadj'] = (1 + crsp['ret']) * (1 + crsp['dlret']) - 1

# find the closest trading day to the end of the month
crsp['monthend'] = crsp['date'] + MonthEnd(0)
crsp['date_diff'] = crsp['monthend'] - crsp['date']
date_temp = crsp.groupby(['permno', 'monthend'])['date_diff'].min()
date_temp = pd.DataFrame(date_temp)  # convert Series to DataFrame
date_temp.reset_index(inplace=True)
date_temp.rename(columns={'date_diff': 'min_diff'}, inplace=True)
crsp = pd.merge(crsp, date_temp, how='left', on=['permno', 'monthend'])
crsp['sig'] = np.where(crsp['date_diff'] == crsp['min_diff'], 1, np.nan)

# label every date of month end
crsp['month_count'] = crsp[crsp['sig'] == 1].groupby(['permno']).cumcount()

# label numbers of months for a firm
month_num = crsp[crsp['sig'] == 1].groupby(['permno'])['month_count'].tail(1)
month_num = month_num.astype(int)
month_num = month_num.reset_index(drop=True)

# mark the number of each month to each day of this month
crsp['month_count'] = crsp.groupby(['permno'])['month_count'].fillna(method='bfill')

# crate a firm list
df_firm = crsp.drop_duplicates(['permno'])
df_firm = df_firm[['permno']]
df_firm['permno'] = df_firm['permno'].astype(int)
df_firm = df_firm.reset_index(drop=True)
df_firm = df_firm.reset_index()
df_firm = df_firm.rename(columns={'index': 'count'})
df_firm['month_num'] = month_num

######################
# Calculate residual #
######################


def get_baspread(df, firm_list):
    """

    :param df: stock dataframe
    :param firm_list: list of firms matching stock dataframe
    :return: dataframe with variance of residual
    """
    for firm, count, prog in zip(firm_list['permno'], firm_list['month_num'], range(firm_list['permno'].count()+1)):
        prog = prog + 1
        print('processing permno %s' % firm, '/', 'finished', '%.2f%%' % ((prog/firm_list['permno'].count())*100))
        for i in range(count + 1):
            # if you want to change the rolling window, please change here: i - 2 means 3 months is a window.
            temp = df[(df['permno'] == firm) & (i - 2 <= df['month_count']) & (df['month_count'] <= i)]
            if temp['permno'].count() < 21:
                pass
            else:
                index = temp.tail(1).index
                X = pd.DataFrame()
                X[['vol', 'prc', 'retadj']] = temp[['vol', 'prc', 'retadj']]
                ill = (abs(X['retadj']) / abs(X['prc'])*X['vol']).mean()
                df.loc[index, 'ill'] = ill
    return df


def sub_df(start, end, step):
    """
    :param start: the quantile to start cutting, usually it should be 0
    :param end: the quantile to end cutting, usually it should be 1
    :param step: quantile step
    :return: a dictionary including all the 'firm_list' dataframe and 'newly grouped stock data' dataframe
    """
    # 按照原来的逻辑先分10组
    temp = {}
    for i, h in zip(np.arange(start, end, step), range(int((end - start) / step))):
        print('processing splitting dataframe:', round(i, 2), 'to', round(i + step, 2))
        if i == 0:  # to get the left point
            temp['firm' + str(h)] = df_firm[df_firm['month_count'] <= df_firm['month_count'].quantile(i + step)]
            temp['crsp' + str(h)] = pd.merge(crsp, temp['firm' + str(h)], how='left',
                                             on='permno').dropna(subset=['month_count'])
        else:
            temp['firm' + str(h)] = df_firm[(df_firm['month_count'].quantile(i) < df_firm['month_count']) & (
                    df_firm['month_count'] <= df_firm['month_count'].quantile(i + step))]
            temp['crsp' + str(h)] = pd.merge(crsp, temp['firm' + str(h)], how='left',
                                             on='permno').dropna(subset=['month_count'])

    # 初始化新的10组df
    new_groups = {f'new_group_{i}': pd.DataFrame() for i in range(10)}

    # 将原来的10组数据均匀地分配到新的10组中，可以确保每个df的计算进度相近
    for key in temp:
        if key.startswith('crsp'):
            group_data = temp[key]
            for i, row in group_data.iterrows():
                new_group_index = len(new_groups[f'new_group_{i % 10}'])
                new_groups[f'new_group_{i % 10}'] = new_groups[f'new_group_{i % 10}'].append(row, ignore_index=True)

    return new_groups


def process(start, end, step):
    """

    :param start: the quantile to start cutting, usually it should be 0
    :param end: the quantile to end cutting, usually it should be 1
    :param step: quantile step
    :return: a dataframe with calculated variance of residual
    """
    df = sub_df(start, end, step)
    pool = mp.Pool()
    p_dict = {}
    for i in range(int((end-start)/step)):
        p_dict['p' + str(i)] = pool.apply_async(get_baspread, (df['crsp%s' % i], df['firm%s' % i],))
    pool.close()
    pool.join()
    result = pd.DataFrame()
    print('processing pd.concat')
    for h in range(int((end-start)/step)):
        result = pd.concat([result, p_dict['p%s' % h].get()])
    return result
# Out:
# C:\Users\123\AppData\Local\Temp\ipykernel_20708\3822443995.py:45: FutureWarning: SeriesGroupBy.fillna is deprecated and will be removed in a future version. Use obj.ffill() or obj.bfill() for forward or backward filling instead. If you want to fill with a single value, use Series.fillna instead
#   crsp['month_count'] = crsp.groupby(['permno'])['month_count'].fillna(method='bfill')
# C:\Users\123\AppData\Local\Temp\ipykernel_20708\3822443995.py:45: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   crsp['month_count'] = crsp.groupby(['permno'])['month_count'].fillna(method='bfill')

# %%
# calculate variance of residual through rolling window
# Note: please split dataframe according to your CPU situation. For example, we split dataframe to (1-0)/0.05 = 20 sub
# dataframes here, so the function will use 20 cores to calculate variance of residual.
crsp = process(0, 1, 0.05)
# Out:
# processing splitting dataframe: 0.0 to 0.05
# processing splitting dataframe: 0.05 to 0.1
# processing splitting dataframe: 0.1 to 0.15
# processing splitting dataframe: 0.15 to 0.2
# processing splitting dataframe: 0.2 to 0.25
# processing splitting dataframe: 0.25 to 0.3
# processing splitting dataframe: 0.3 to 0.35
# processing splitting dataframe: 0.35 to 0.4
# processing splitting dataframe: 0.4 to 0.45
# processing splitting dataframe: 0.45 to 0.5
# processing splitting dataframe: 0.5 to 0.55
# processing splitting dataframe: 0.55 to 0.6
# processing splitting dataframe: 0.6 to 0.65
# processing splitting dataframe: 0.65 to 0.7
# processing splitting dataframe: 0.7 to 0.75
# processing splitting dataframe: 0.75 to 0.8
# processing splitting dataframe: 0.8 to 0.85
# processing splitting dataframe: 0.85 to 0.9
# processing splitting dataframe: 0.9 to 0.95
# processing splitting dataframe: 0.95 to 1.0
# processing permno 10001 / finished 0.13%
# processing permno 10025 / finished 0.27%
# processing permno 10026 / finished 0.40%
# processing permno 10028 / finished 0.54%
# processing permno 10032 / finished 0.67%
# processing permno 10044 / finished 0.81%
# processing permno 10051 / finished 0.94%
# processing permno 10065 / finished 1.08%
# processing permno 10066 / finished 1.21%
# processing permno 10104 / finished 1.35%
# processing permno 10107 / finished 1.48%
# processing permno 10113 / finished 1.62%
# processing permno 10116 / finished 1.75%
# processing permno 10138 / finished 1.88%
# processing permno 10145 / finished 2.02%
# processing permno 10147 / finished 2.15%
# processing permno 10158 / finished 2.29%
# processing permno 10180 / finished 2.42%
# processing permno 10182 / finished 2.56%
# processing permno 10200 / finished 2.69%
# processing permno 10201 / finished 2.83%
# processing permno 10207 / finished 2.96%
# processing permno 10220 / finished 3.10%
# processing permno 10232 / finished 3.23%
# processing permno 10239 / finished 3.36%
# processing permno 10252 / finished 3.50%
# processing permno 10253 / finished 3.63%
# processing permno 10257 / finished 3.77%
# processing permno 10258 / finished 3.90%
# processing permno 10259 / finished 4.04%
# processing permno 10294 / finished 4.17%
# processing permno 10297 / finished 4.31%
# processing permno 10299 / finished 4.44%
# processing permno 10302 / finished 4.58%
# processing permno 10308 / finished 4.71%
# processing permno 10318 / finished 4.85%
# processing permno 10333 / finished 4.98%
# processing permno 10353 / finished 5.11%
# processing permno 10355 / finished 5.25%
# processing permno 10363 / finished 5.38%
# processing permno 10375 / finished 5.52%
# processing permno 10382 / finished 5.65%
# processing permno 10395 / finished 5.79%
# processing permno 10397 / finished 5.92%
# processing permno 10421 / finished 6.06%
# processing permno 10443 / finished 6.19%
# processing permno 10463 / finished 6.33%
# processing permno 10501 / finished 6.46%
# processing permno 10514 / finished 6.59%
# processing permno 10516 / finished 6.73%
# processing permno 10517 / finished 6.86%
# processing permno 10530 / finished 7.00%
# processing permno 10547 / finished 7.13%
# processing permno 10550 / finished 7.27%
# processing permno 10606 / finished 7.40%
# processing permno 10629 / finished 7.54%
# processing permno 10645 / finished 7.67%
# processing permno 10649 / finished 7.81%
# processing permno 10656 / finished 7.94%
# processing permno 10661 / finished 8.08%
# processing permno 10667 / finished 8.21%
# processing permno 10693 / finished 8.34%
# processing permno 10696 / finished 8.48%
# processing permno 10777 / finished 8.61%
# processing permno 10779 / finished 8.75%
# processing permno 10781 / finished 8.88%
# processing permno 10812 / finished 9.02%
# processing permno 10838 / finished 9.15%
# processing permno 10853 / finished 9.29%
# processing permno 10860 / finished 9.42%
# processing permno 10866 / finished 9.56%
# processing permno 10874 / finished 9.69%
# processing permno 10886 / finished 9.83%
# processing permno 10890 / finished 9.96%
# processing permno 10892 / finished 10.09%
# processing permno 10901 / finished 10.23%
# processing permno 10909 / finished 10.36%
# processing permno 10913 / finished 10.50%
# processing permno 10932 / finished 10.63%
# processing permno 10933 / finished 10.77%
# processing permno 10952 / finished 10.90%
# processing permno 10966 / finished 11.04%
# processing permno 11003 / finished 11.17%
# processing permno 11006 / finished 11.31%
# processing permno 11018 / finished 11.44%
# processing permno 11043 / finished 11.57%
# processing permno 11144 / finished 11.71%
# processing permno 11153 / finished 11.84%
# processing permno 11154 / finished 11.98%
# processing permno 11174 / finished 12.11%
# processing permno 11182 / finished 12.25%
# processing permno 11203 / finished 12.38%
# processing permno 11208 / finished 12.52%
# processing permno 11246 / finished 12.65%
# processing permno 11264 / finished 12.79%
# processing permno 11267 / finished 12.92%
# processing permno 11275 / finished 13.06%
# processing permno 11285 / finished 13.19%
# processing permno 11292 / finished 13.32%
# processing permno 11293 / finished 13.46%
# processing permno 11308 / finished 13.59%
# processing permno 11343 / finished 13.73%
# processing permno 11348 / finished 13.86%
# processing permno 11361 / finished 14.00%
# processing permno 11363 / finished 14.13%
# processing permno 11368 / finished 14.27%
# processing permno 11369 / finished 14.40%
# processing permno 11370 / finished 14.54%
# processing permno 11378 / finished 14.67%
# processing permno 11379 / finished 14.80%
# processing permno 11394 / finished 14.94%
# processing permno 11397 / finished 15.07%
# processing permno 11403 / finished 15.21%
# processing permno 11404 / finished 15.34%
# processing permno 11407 / finished 15.48%
# processing permno 11441 / finished 15.61%
# processing permno 11442 / finished 15.75%
# processing permno 11481 / finished 15.88%
# processing permno 11499 / finished 16.02%
# processing permno 11511 / finished 16.15%
# processing permno 11533 / finished 16.29%
# processing permno 11547 / finished 16.42%
# processing permno 11552 / finished 16.55%
# processing permno 11565 / finished 16.69%
# processing permno 11581 / finished 16.82%
# processing permno 11587 / finished 16.96%
# processing permno 11593 / finished 17.09%
# processing permno 11600 / finished 17.23%
# processing permno 11618 / finished 17.36%
# processing permno 11628 / finished 17.50%
# processing permno 11636 / finished 17.63%
# processing permno 11638 / finished 17.77%
# processing permno 11641 / finished 17.90%
# processing permno 11644 / finished 18.03%
# processing permno 11648 / finished 18.17%
# processing permno 11654 / finished 18.30%
# processing permno 11664 / finished 18.44%
# processing permno 11674 / finished 18.57%
# processing permno 11691 / finished 18.71%
# processing permno 11701 / finished 18.84%
# processing permno 11703 / finished 18.98%
# processing permno 11707 / finished 19.11%
# processing permno 11731 / finished 19.25%
# processing permno 11748 / finished 19.38%
# processing permno 11750 / finished 19.52%
# processing permno 11752 / finished 19.65%
# processing permno 11762 / finished 19.78%
# processing permno 11775 / finished 19.92%
# processing permno 11786 / finished 20.05%
# processing permno 11790 / finished 20.19%
# processing permno 11803 / finished 20.32%
# processing permno 11809 / finished 20.46%
# processing permno 11825 / finished 20.59%
# processing permno 11844 / finished 20.73%
# processing permno 11845 / finished 20.86%
# processing permno 11850 / finished 21.00%
# processing permno 11884 / finished 21.13%
# processing permno 11891 / finished 21.27%
# processing permno 11896 / finished 21.40%
# processing permno 11955 / finished 21.53%
# processing permno 11990 / finished 21.67%
# processing permno 11992 / finished 21.80%
# processing permno 11995 / finished 21.94%
# processing permno 11996 / finished 22.07%
# processing permno 12007 / finished 22.21%
# processing permno 12008 / finished 22.34%
# processing permno 12009 / finished 22.48%
# processing permno 12011 / finished 22.61%
# processing permno 12015 / finished 22.75%
# processing permno 12017 / finished 22.88%
# processing permno 12018 / finished 23.01%
# processing permno 12023 / finished 23.15%
# processing permno 12026 / finished 23.28%
# processing permno 12027 / finished 23.42%
# processing permno 12030 / finished 23.55%
# processing permno 12034 / finished 23.69%
# processing permno 12035 / finished 23.82%
# processing permno 12036 / finished 23.96%
# processing permno 12039 / finished 24.09%
# processing permno 12047 / finished 24.23%
# processing permno 12049 / finished 24.36%
# processing permno 12051 / finished 24.50%
# processing permno 12052 / finished 24.63%
# processing permno 12054 / finished 24.76%
# processing permno 12057 / finished 24.90%
# processing permno 12059 / finished 25.03%
# processing permno 12060 / finished 25.17%
# processing permno 12062 / finished 25.30%
# processing permno 12064 / finished 25.44%
# processing permno 12065 / finished 25.57%
# processing permno 12066 / finished 25.71%
# processing permno 12068 / finished 25.84%
# processing permno 12070 / finished 25.98%
# processing permno 12072 / finished 26.11%
# processing permno 12073 / finished 26.24%
# processing permno 12075 / finished 26.38%
# processing permno 12076 / finished 26.51%
# processing permno 12078 / finished 26.65%
# processing permno 12080 / finished 26.78%
# processing permno 12082 / finished 26.92%
# processing permno 12084 / finished 27.05%
# processing permno 12088 / finished 27.19%
# processing permno 12089 / finished 27.32%
# processing permno 12093 / finished 27.46%
# processing permno 12097 / finished 27.59%
# processing permno 12098 / finished 27.73%
# processing permno 12103 / finished 27.86%
# processing permno 12105 / finished 27.99%
# processing permno 12109 / finished 28.13%
# processing permno 12146 / finished 28.26%
# processing permno 12149 / finished 28.40%
# processing permno 12166 / finished 28.53%
# processing permno 12173 / finished 28.67%
# processing permno 12189 / finished 28.80%
# processing permno 12190 / finished 28.94%
# processing permno 12209 / finished 29.07%
# processing permno 12211 / finished 29.21%
# processing permno 12219 / finished 29.34%
# processing permno 12226 / finished 29.48%
# processing permno 12248 / finished 29.61%
# processing permno 12266 / finished 29.74%
# processing permno 12287 / finished 29.88%
# processing permno 12288 / finished 30.01%
# processing permno 12289 / finished 30.15%
# processing permno 12292 / finished 30.28%
# processing permno 12293 / finished 30.42%
# processing permno 12294 / finished 30.55%
# processing permno 12295 / finished 30.69%
# processing permno 12296 / finished 30.82%
# processing permno 12297 / finished 30.96%
# processing permno 12301 / finished 31.09%
# processing permno 12302 / finished 31.22%
# processing permno 12303 / finished 31.36%
# processing permno 12304 / finished 31.49%
# processing permno 12305 / finished 31.63%
# processing permno 12306 / finished 31.76%
# processing permno 12307 / finished 31.90%
# processing permno 12308 / finished 32.03%
# processing permno 12309 / finished 32.17%
# processing permno 12310 / finished 32.30%
# processing permno 12312 / finished 32.44%
# processing permno 12313 / finished 32.57%
# processing permno 12314 / finished 32.71%
# processing permno 12315 / finished 32.84%
# processing permno 12316 / finished 32.97%
# processing permno 12317 / finished 33.11%
# processing permno 12318 / finished 33.24%
# processing permno 12321 / finished 33.38%
# processing permno 12322 / finished 33.51%
# processing permno 12323 / finished 33.65%
# processing permno 12324 / finished 33.78%
# processing permno 12325 / finished 33.92%
# processing permno 12326 / finished 34.05%
# processing permno 12329 / finished 34.19%
# processing permno 12330 / finished 34.32%
# processing permno 12331 / finished 34.45%
# processing permno 12332 / finished 34.59%
# processing permno 12333 / finished 34.72%
# processing permno 12334 / finished 34.86%
# processing permno 12338 / finished 34.99%
# processing permno 12339 / finished 35.13%
# processing permno 12340 / finished 35.26%
# processing permno 12341 / finished 35.40%
# processing permno 12345 / finished 35.53%
# processing permno 12347 / finished 35.67%
# processing permno 12348 / finished 35.80%
# processing permno 12350 / finished 35.94%
# processing permno 12352 / finished 36.07%
# processing permno 12355 / finished 36.20%
# processing permno 12356 / finished 36.34%
# processing permno 12357 / finished 36.47%
# processing permno 12358 / finished 36.61%
# processing permno 12360 / finished 36.74%
# processing permno 12362 / finished 36.88%
# processing permno 12363 / finished 37.01%
# processing permno 12365 / finished 37.15%
# processing permno 12366 / finished 37.28%
# processing permno 12367 / finished 37.42%
# processing permno 12368 / finished 37.55%
# processing permno 12369 / finished 37.69%
# processing permno 12370 / finished 37.82%
# processing permno 12371 / finished 37.95%
# processing permno 12372 / finished 38.09%
# processing permno 12373 / finished 38.22%
# processing permno 12374 / finished 38.36%
# processing permno 12376 / finished 38.49%
# processing permno 12377 / finished 38.63%
# processing permno 12379 / finished 38.76%
# processing permno 12380 / finished 38.90%
# processing permno 12384 / finished 39.03%
# processing permno 12385 / finished 39.17%
# processing permno 12389 / finished 39.30%
# processing permno 12390 / finished 39.43%
# processing permno 12391 / finished 39.57%
# processing permno 12392 / finished 39.70%
# processing permno 12397 / finished 39.84%
# processing permno 12400 / finished 39.97%
# processing permno 12402 / finished 40.11%
# processing permno 12405 / finished 40.24%
# processing permno 12410 / finished 40.38%
# processing permno 12411 / finished 40.51%
# processing permno 12412 / finished 40.65%
# processing permno 12413 / finished 40.78%
# processing permno 12431 / finished 40.92%
# processing permno 12437 / finished 41.05%
# processing permno 12438 / finished 41.18%
# processing permno 12442 / finished 41.32%
# processing permno 12443 / finished 41.45%
# processing permno 12444 / finished 41.59%
# processing permno 12445 / finished 41.72%
# processing permno 12446 / finished 41.86%
# processing permno 12447 / finished 41.99%
# processing permno 12448 / finished 42.13%
# processing permno 12449 / finished 42.26%
# processing permno 12451 / finished 42.40%
# processing permno 12452 / finished 42.53%
# processing permno 12453 / finished 42.66%
# processing permno 12457 / finished 42.80%
# processing permno 12461 / finished 42.93%
# processing permno 12462 / finished 43.07%
# processing permno 12463 / finished 43.20%
# processing permno 12465 / finished 43.34%
# processing permno 12469 / finished 43.47%
# processing permno 12470 / finished 43.61%
# processing permno 12471 / finished 43.74%
# processing permno 12472 / finished 43.88%
# processing permno 12473 / finished 44.01%
# processing permno 12476 / finished 44.15%
# processing permno 12477 / finished 44.28%
# processing permno 12478 / finished 44.41%
# processing permno 12480 / finished 44.55%
# processing permno 12481 / finished 44.68%
# processing permno 12486 / finished 44.82%
# processing permno 12487 / finished 44.95%
# processing permno 12488 / finished 45.09%
# processing permno 12489 / finished 45.22%
# processing permno 12490 / finished 45.36%
# processing permno 12492 / finished 45.49%
# processing permno 12493 / finished 45.63%
# processing permno 12494 / finished 45.76%
# processing permno 12495 / finished 45.90%
# processing permno 12496 / finished 46.03%
# processing permno 12497 / finished 46.16%
# processing permno 12498 / finished 46.30%
# processing permno 12500 / finished 46.43%
# processing permno 12501 / finished 46.57%
# processing permno 12502 / finished 46.70%
# processing permno 12503 / finished 46.84%
# processing permno 12505 / finished 46.97%
# processing permno 12508 / finished 47.11%
# processing permno 12509 / finished 47.24%
# processing permno 12510 / finished 47.38%
# processing permno 12513 / finished 47.51%
# processing permno 12514 / finished 47.64%
# processing permno 12515 / finished 47.78%
# processing permno 12516 / finished 47.91%
# processing permno 12521 / finished 48.05%
# processing permno 12523 / finished 48.18%
# processing permno 12527 / finished 48.32%
# processing permno 12528 / finished 48.45%
# processing permno 12530 / finished 48.59%
# processing permno 12531 / finished 48.72%
# processing permno 12533 / finished 48.86%
# processing permno 12534 / finished 48.99%
# processing permno 12535 / finished 49.13%
# processing permno 12536 / finished 49.26%
# processing permno 12537 / finished 49.39%
# processing permno 12540 / finished 49.53%
# processing permno 12541 / finished 49.66%
# processing permno 12542 / finished 49.80%
# processing permno 12543 / finished 49.93%
# processing permno 12552 / finished 50.07%
# processing permno 12553 / finished 50.20%
# processing permno 12556 / finished 50.34%
# processing permno 12557 / finished 50.47%
# processing permno 12558 / finished 50.61%
# processing permno 12559 / finished 50.74%
# processing permno 12560 / finished 50.87%
# processing permno 12561 / finished 51.01%
# processing permno 12564 / finished 51.14%
# processing permno 12565 / finished 51.28%
# processing permno 12566 / finished 51.41%
# processing permno 12569 / finished 51.55%
# processing permno 12570 / finished 51.68%
# processing permno 12573 / finished 51.82%
# processing permno 12575 / finished 51.95%
# processing permno 12577 / finished 52.09%
# processing permno 12578 / finished 52.22%
# processing permno 12579 / finished 52.36%
# processing permno 12582 / finished 52.49%
# processing permno 12583 / finished 52.62%
# processing permno 12584 / finished 52.76%
# processing permno 12585 / finished 52.89%
# processing permno 12587 / finished 53.03%
# processing permno 12588 / finished 53.16%
# processing permno 12591 / finished 53.30%
# processing permno 12592 / finished 53.43%
# processing permno 12593 / finished 53.57%
# processing permno 12594 / finished 53.70%
# processing permno 12595 / finished 53.84%
# processing permno 12596 / finished 53.97%
# processing permno 12615 / finished 54.10%
# processing permno 12621 / finished 54.24%
# processing permno 12622 / finished 54.37%
# processing permno 12623 / finished 54.51%
# processing permno 12624 / finished 54.64%
# processing permno 12625 / finished 54.78%
# processing permno 12628 / finished 54.91%
# processing permno 12629 / finished 55.05%
# processing permno 12631 / finished 55.18%
# processing permno 12632 / finished 55.32%
# processing permno 12633 / finished 55.45%
# processing permno 12636 / finished 55.59%
# processing permno 12637 / finished 55.72%
# processing permno 12638 / finished 55.85%
# processing permno 12639 / finished 55.99%
# processing permno 12640 / finished 56.12%
# processing permno 12641 / finished 56.26%
# processing permno 12644 / finished 56.39%
# processing permno 12645 / finished 56.53%
# processing permno 12646 / finished 56.66%
# processing permno 12647 / finished 56.80%
# processing permno 12648 / finished 56.93%
# processing permno 12649 / finished 57.07%
# processing permno 12650 / finished 57.20%
# processing permno 12651 / finished 57.34%
# processing permno 12652 / finished 57.47%
# processing permno 12653 / finished 57.60%
# processing permno 12654 / finished 57.74%
# processing permno 12655 / finished 57.87%
# processing permno 12656 / finished 58.01%
# processing permno 12657 / finished 58.14%
# processing permno 12658 / finished 58.28%
# processing permno 12659 / finished 58.41%
# processing permno 12660 / finished 58.55%
# processing permno 12662 / finished 58.68%
# processing permno 12665 / finished 58.82%
# processing permno 12666 / finished 58.95%
# processing permno 12667 / finished 59.08%
# processing permno 12668 / finished 59.22%
# processing permno 12671 / finished 59.35%
# processing permno 12672 / finished 59.49%
# processing permno 12673 / finished 59.62%
# processing permno 12674 / finished 59.76%
# processing permno 12675 / finished 59.89%
# processing permno 12676 / finished 60.03%
# processing permno 12679 / finished 60.16%
# processing permno 12680 / finished 60.30%
# processing permno 12681 / finished 60.43%
# processing permno 12683 / finished 60.57%
# processing permno 12684 / finished 60.70%
# processing permno 12689 / finished 60.83%
# processing permno 12690 / finished 60.97%
# processing permno 12693 / finished 61.10%
# processing permno 12695 / finished 61.24%
# processing permno 12696 / finished 61.37%
# processing permno 12697 / finished 61.51%
# processing permno 12698 / finished 61.64%
# processing permno 12699 / finished 61.78%
# processing permno 12717 / finished 61.91%
# processing permno 12720 / finished 62.05%
# processing permno 12727 / finished 62.18%
# processing permno 12728 / finished 62.31%
# processing permno 12729 / finished 62.45%
# processing permno 12732 / finished 62.58%
# processing permno 12738 / finished 62.72%
# processing permno 12739 / finished 62.85%
# processing permno 12740 / finished 62.99%
# processing permno 12741 / finished 63.12%
# processing permno 12742 / finished 63.26%
# processing permno 12744 / finished 63.39%
# processing permno 12745 / finished 63.53%
# processing permno 12746 / finished 63.66%
# processing permno 12747 / finished 63.80%
# processing permno 12748 / finished 63.93%
# processing permno 12751 / finished 64.06%
# processing permno 12753 / finished 64.20%
# processing permno 12754 / finished 64.33%
# processing permno 12756 / finished 64.47%
# processing permno 12758 / finished 64.60%
# processing permno 12759 / finished 64.74%
# processing permno 12781 / finished 64.87%
# processing permno 12783 / finished 65.01%
# processing permno 12785 / finished 65.14%
# processing permno 12786 / finished 65.28%
# processing permno 12788 / finished 65.41%
# processing permno 12789 / finished 65.55%
# processing permno 12791 / finished 65.68%
# processing permno 12792 / finished 65.81%
# processing permno 12795 / finished 65.95%
# processing permno 12796 / finished 66.08%
# processing permno 12797 / finished 66.22%
# processing permno 12798 / finished 66.35%
# processing permno 12799 / finished 66.49%
# processing permno 12826 / finished 66.62%
# processing permno 12828 / finished 66.76%
# processing permno 12831 / finished 66.89%
# processing permno 12832 / finished 67.03%
# processing permno 12833 / finished 67.16%
# processing permno 12834 / finished 67.29%
# processing permno 12835 / finished 67.43%
# processing permno 12839 / finished 67.56%
# processing permno 12840 / finished 67.70%
# processing permno 12841 / finished 67.83%
# processing permno 12842 / finished 67.97%
# processing permno 12843 / finished 68.10%
# processing permno 12844 / finished 68.24%
# processing permno 12847 / finished 68.37%
# processing permno 12850 / finished 68.51%
# processing permno 12852 / finished 68.64%
# processing permno 12867 / finished 68.78%
# processing permno 12868 / finished 68.91%
# processing permno 12870 / finished 69.04%
# processing permno 12871 / finished 69.18%
# processing permno 12872 / finished 69.31%
# processing permno 12873 / finished 69.45%
# processing permno 12874 / finished 69.58%
# processing permno 12875 / finished 69.72%
# processing permno 12876 / finished 69.85%
# processing permno 12877 / finished 69.99%
# processing permno 12878 / finished 70.12%
# processing permno 12880 / finished 70.26%
# processing permno 12881 / finished 70.39%
# processing permno 12884 / finished 70.52%
# processing permno 12885 / finished 70.66%
# processing permno 12886 / finished 70.79%
# processing permno 12890 / finished 70.93%
# processing permno 12891 / finished 71.06%
# processing permno 12892 / finished 71.20%
# processing permno 12893 / finished 71.33%
# processing permno 12894 / finished 71.47%
# processing permno 12895 / finished 71.60%
# processing permno 12899 / finished 71.74%
# processing permno 12901 / finished 71.87%
# processing permno 12902 / finished 72.01%
# processing permno 12904 / finished 72.14%
# processing permno 12905 / finished 72.27%
# processing permno 12906 / finished 72.41%
# processing permno 12908 / finished 72.54%
# processing permno 12911 / finished 72.68%
# processing permno 12912 / finished 72.81%
# processing permno 12913 / finished 72.95%
# processing permno 12914 / finished 73.08%
# processing permno 12915 / finished 73.22%
# processing permno 12916 / finished 73.35%
# processing permno 12919 / finished 73.49%
# processing permno 12920 / finished 73.62%
# processing permno 12922 / finished 73.76%
# processing permno 12923 / finished 73.89%
# processing permno 12924 / finished 74.02%
# processing permno 12927 / finished 74.16%
# processing permno 12928 / finished 74.29%
# processing permno 12946 / finished 74.43%
# processing permno 12947 / finished 74.56%
# processing permno 12948 / finished 74.70%
# processing permno 12949 / finished 74.83%
# processing permno 12952 / finished 74.97%
# processing permno 12953 / finished 75.10%
# processing permno 12954 / finished 75.24%
# processing permno 12957 / finished 75.37%
# processing permno 12960 / finished 75.50%
# processing permno 12961 / finished 75.64%
# processing permno 12963 / finished 75.77%
# processing permno 12965 / finished 75.91%
# processing permno 12971 / finished 76.04%
# processing permno 12972 / finished 76.18%
# processing permno 12974 / finished 76.31%
# processing permno 12975 / finished 76.45%
# processing permno 12978 / finished 76.58%
# processing permno 12979 / finished 76.72%
# processing permno 12980 / finished 76.85%
# processing permno 12981 / finished 76.99%
# processing permno 12982 / finished 77.12%
# processing permno 12983 / finished 77.25%
# processing permno 12986 / finished 77.39%
# processing permno 12988 / finished 77.52%
# processing permno 12991 / finished 77.66%
# processing permno 12994 / finished 77.79%
# processing permno 12995 / finished 77.93%
# processing permno 12996 / finished 78.06%
# processing permno 12997 / finished 78.20%
# processing permno 12998 / finished 78.33%
# processing permno 12999 / finished 78.47%
# processing permno 13000 / finished 78.60%
# processing permno 13001 / finished 78.73%
# processing permno 13002 / finished 78.87%
# processing permno 13003 / finished 79.00%
# processing permno 13006 / finished 79.14%
# processing permno 13007 / finished 79.27%
# processing permno 13008 / finished 79.41%
# processing permno 13009 / finished 79.54%
# processing permno 13013 / finished 79.68%
# processing permno 13014 / finished 79.81%
# processing permno 13015 / finished 79.95%
# processing permno 13016 / finished 80.08%
# processing permno 13017 / finished 80.22%
# processing permno 13019 / finished 80.35%
# processing permno 13022 / finished 80.48%
# processing permno 13023 / finished 80.62%
# processing permno 13024 / finished 80.75%
# processing permno 13025 / finished 80.89%
# processing permno 13026 / finished 81.02%
# processing permno 13027 / finished 81.16%
# processing permno 13029 / finished 81.29%
# processing permno 13030 / finished 81.43%
# processing permno 13031 / finished 81.56%
# processing permno 13032 / finished 81.70%
# processing permno 13033 / finished 81.83%
# processing permno 13034 / finished 81.97%
# processing permno 13035 / finished 82.10%
# processing permno 13036 / finished 82.23%
# processing permno 13037 / finished 82.37%
# processing permno 13038 / finished 82.50%
# processing permno 13041 / finished 82.64%
# processing permno 13046 / finished 82.77%
# processing permno 13049 / finished 82.91%
# processing permno 13076 / finished 83.04%
# processing permno 13077 / finished 83.18%
# processing permno 13079 / finished 83.31%
# processing permno 13080 / finished 83.45%
# processing permno 13081 / finished 83.58%
# processing permno 13082 / finished 83.71%
# processing permno 13084 / finished 83.85%
# processing permno 13085 / finished 83.98%
# processing permno 13089 / finished 84.12%
# processing permno 13090 / finished 84.25%
# processing permno 13091 / finished 84.39%
# processing permno 13092 / finished 84.52%
# processing permno 13093 / finished 84.66%
# processing permno 13097 / finished 84.79%
# processing permno 13102 / finished 84.93%
# processing permno 13103 / finished 85.06%
# processing permno 13104 / finished 85.20%
# processing permno 13105 / finished 85.33%
# processing permno 13106 / finished 85.46%
# processing permno 13107 / finished 85.60%
# processing permno 13108 / finished 85.73%
# processing permno 13109 / finished 85.87%
# processing permno 13110 / finished 86.00%
# processing permno 13111 / finished 86.14%
# processing permno 13112 / finished 86.27%
# processing permno 13113 / finished 86.41%
# processing permno 13114 / finished 86.54%
# processing permno 13116 / finished 86.68%
# processing permno 13117 / finished 86.81%
# processing permno 13121 / finished 86.94%
# processing permno 13122 / finished 87.08%
# processing permno 13124 / finished 87.21%
# processing permno 13126 / finished 87.35%
# processing permno 13129 / finished 87.48%
# processing permno 13130 / finished 87.62%
# processing permno 13131 / finished 87.75%
# processing permno 13132 / finished 87.89%
# processing permno 13133 / finished 88.02%
# processing permno 13134 / finished 88.16%
# processing permno 13137 / finished 88.29%
# processing permno 13138 / finished 88.43%
# processing permno 13139 / finished 88.56%
# processing permno 13140 / finished 88.69%
# processing permno 13141 / finished 88.83%
# processing permno 13142 / finished 88.96%
# processing permno 13145 / finished 89.10%
# processing permno 13159 / finished 89.23%
# processing permno 13160 / finished 89.37%
# processing permno 13161 / finished 89.50%
# processing permno 13162 / finished 89.64%
# processing permno 13163 / finished 89.77%
# processing permno 13167 / finished 89.91%
# processing permno 13168 / finished 90.04%
# processing permno 13169 / finished 90.17%
# processing permno 13172 / finished 90.31%
# processing permno 13174 / finished 90.44%
# processing permno 13176 / finished 90.58%
# processing permno 13180 / finished 90.71%
# processing permno 13181 / finished 90.85%
# processing permno 13182 / finished 90.98%
# processing permno 13185 / finished 91.12%
# processing permno 13188 / finished 91.25%
# processing permno 13189 / finished 91.39%
# processing permno 13190 / finished 91.52%
# processing permno 13191 / finished 91.66%
# processing permno 13193 / finished 91.79%
# processing permno 13195 / finished 91.92%
# processing permno 13196 / finished 92.06%
# processing permno 13198 / finished 92.19%
# processing permno 13200 / finished 92.33%
# processing permno 13201 / finished 92.46%
# processing permno 13202 / finished 92.60%
# processing permno 13203 / finished 92.73%
# processing permno 13204 / finished 92.87%
# processing permno 13206 / finished 93.00%
# processing permno 13208 / finished 93.14%
# processing permno 13209 / finished 93.27%
# processing permno 13210 / finished 93.41%
# processing permno 13211 / finished 93.54%
# processing permno 13212 / finished 93.67%
# processing permno 13213 / finished 93.81%
# processing permno 13214 / finished 93.94%
# processing permno 13217 / finished 94.08%
# processing permno 13218 / finished 94.21%
# processing permno 13219 / finished 94.35%
# processing permno 13220 / finished 94.48%
# processing permno 13221 / finished 94.62%
# processing permno 13226 / finished 94.75%
# processing permno 13228 / finished 94.89%
# processing permno 13229 / finished 95.02%
# processing permno 13230 / finished 95.15%
# processing permno 13233 / finished 95.29%
# processing permno 13234 / finished 95.42%
# processing permno 13235 / finished 95.56%
# processing permno 13236 / finished 95.69%
# processing permno 13240 / finished 95.83%
# processing permno 13241 / finished 95.96%
# processing permno 13242 / finished 96.10%
# processing permno 13243 / finished 96.23%
# processing permno 13244 / finished 96.37%
# processing permno 13245 / finished 96.50%
# processing permno 13246 / finished 96.64%
# processing permno 13249 / finished 96.77%
# processing permno 13251 / finished 96.90%
# processing permno 13252 / finished 97.04%
# processing permno 13253 / finished 97.17%
# processing permno 13254 / finished 97.31%
# processing permno 13255 / finished 97.44%
# processing permno 13260 / finished 97.58%
# processing permno 13261 / finished 97.71%
# processing permno 13262 / finished 97.85%
# processing permno 13263 / finished 97.98%
# processing permno 13264 / finished 98.12%
# processing permno 13265 / finished 98.25%
# processing permno 13267 / finished 98.38%
# processing permno 13268 / finished 98.52%
# processing permno 13273 / finished 98.65%
# processing permno 13278 / finished 98.79%
# processing permno 13279 / finished 98.92%
# processing permno 13280 / finished 99.06%
# processing permno 13284 / finished 99.19%
# processing permno 13286 / finished 99.33%
# processing permno 13287 / finished 99.46%
# processing permno 13288 / finished 99.60%
# processing permno 13289 / finished 99.73%
# processing permno 13292 / finished 99.87%
# processing permno 13293 / finished 100.00%
# 已处理分块 1/20
# processing permno 13295 / finished 0.13%
# processing permno 13296 / finished 0.27%
# processing permno 13297 / finished 0.40%
# processing permno 13299 / finished 0.54%
# processing permno 13300 / finished 0.67%
# processing permno 13301 / finished 0.81%
# processing permno 13302 / finished 0.94%
# processing permno 13303 / finished 1.08%
# processing permno 13305 / finished 1.21%
# processing permno 13308 / finished 1.35%
# processing permno 13309 / finished 1.48%
# processing permno 13310 / finished 1.62%
# processing permno 13314 / finished 1.75%
# processing permno 13315 / finished 1.88%
# processing permno 13316 / finished 2.02%
# processing permno 13317 / finished 2.15%
# processing permno 13318 / finished 2.29%
# processing permno 13319 / finished 2.42%
# processing permno 13321 / finished 2.56%
# processing permno 13322 / finished 2.69%
# processing permno 13323 / finished 2.83%
# processing permno 13324 / finished 2.96%
# processing permno 13325 / finished 3.10%
# processing permno 13326 / finished 3.23%
# processing permno 13327 / finished 3.36%
# processing permno 13328 / finished 3.50%
# processing permno 13329 / finished 3.63%
# processing permno 13330 / finished 3.77%
# processing permno 13332 / finished 3.90%
# processing permno 13333 / finished 4.04%
# processing permno 13334 / finished 4.17%
# processing permno 13335 / finished 4.31%
# processing permno 13337 / finished 4.44%
# processing permno 13340 / finished 4.58%
# processing permno 13341 / finished 4.71%
# processing permno 13342 / finished 4.85%
# processing permno 13343 / finished 4.98%
# processing permno 13344 / finished 5.11%
# processing permno 13345 / finished 5.25%
# processing permno 13348 / finished 5.38%
# processing permno 13349 / finished 5.52%
# processing permno 13350 / finished 5.65%
# processing permno 13351 / finished 5.79%
# processing permno 13352 / finished 5.92%
# processing permno 13353 / finished 6.06%
# processing permno 13356 / finished 6.19%
# processing permno 13357 / finished 6.33%
# processing permno 13358 / finished 6.46%
# processing permno 13360 / finished 6.59%
# processing permno 13361 / finished 6.73%
# processing permno 13364 / finished 6.86%
# processing permno 13365 / finished 7.00%
# processing permno 13366 / finished 7.13%
# processing permno 13367 / finished 7.27%
# processing permno 13368 / finished 7.40%
# processing permno 13369 / finished 7.54%
# processing permno 13373 / finished 7.67%
# processing permno 13375 / finished 7.81%
# processing permno 13376 / finished 7.94%
# processing permno 13377 / finished 8.08%
# processing permno 13379 / finished 8.21%
# processing permno 13380 / finished 8.34%
# processing permno 13381 / finished 8.48%
# processing permno 13382 / finished 8.61%
# processing permno 13384 / finished 8.75%
# processing permno 13385 / finished 8.88%
# processing permno 13386 / finished 9.02%
# processing permno 13387 / finished 9.15%
# processing permno 13388 / finished 9.29%
# processing permno 13392 / finished 9.42%
# processing permno 13393 / finished 9.56%
# processing permno 13394 / finished 9.69%
# processing permno 13395 / finished 9.83%
# processing permno 13396 / finished 9.96%
# processing permno 13399 / finished 10.09%
# processing permno 13400 / finished 10.23%
# processing permno 13401 / finished 10.36%
# processing permno 13403 / finished 10.50%
# processing permno 13405 / finished 10.63%
# processing permno 13407 / finished 10.77%
# processing permno 13408 / finished 10.90%
# processing permno 13409 / finished 11.04%
# processing permno 13410 / finished 11.17%
# processing permno 13411 / finished 11.31%
# processing permno 13412 / finished 11.44%
# processing permno 13425 / finished 11.57%
# processing permno 13428 / finished 11.71%
# processing permno 13429 / finished 11.84%
# processing permno 13431 / finished 11.98%
# processing permno 13432 / finished 12.11%
# processing permno 13433 / finished 12.25%
# processing permno 13436 / finished 12.38%
# processing permno 13437 / finished 12.52%
# processing permno 13438 / finished 12.65%
# processing permno 13439 / finished 12.79%
# processing permno 13440 / finished 12.92%
# processing permno 13441 / finished 13.06%
# processing permno 13444 / finished 13.19%
# processing permno 13445 / finished 13.32%
# processing permno 13446 / finished 13.46%
# processing permno 13447 / finished 13.59%
# processing permno 13452 / finished 13.73%
# processing permno 13453 / finished 13.86%
# processing permno 13454 / finished 14.00%
# processing permno 13455 / finished 14.13%
# processing permno 13456 / finished 14.27%
# processing permno 13499 / finished 14.40%
# processing permno 13501 / finished 14.54%
# processing permno 13502 / finished 14.67%
# processing permno 13503 / finished 14.80%
# processing permno 13504 / finished 14.94%
# processing permno 13505 / finished 15.07%
# processing permno 13507 / finished 15.21%
# processing permno 13508 / finished 15.34%
# processing permno 13509 / finished 15.48%
# processing permno 13510 / finished 15.61%
# processing permno 13511 / finished 15.75%
# processing permno 13512 / finished 15.88%
# processing permno 13513 / finished 16.02%
# processing permno 13517 / finished 16.15%
# processing permno 13518 / finished 16.29%
# processing permno 13519 / finished 16.42%
# processing permno 13520 / finished 16.55%
# processing permno 13521 / finished 16.69%
# processing permno 13524 / finished 16.82%
# processing permno 13527 / finished 16.96%
# processing permno 13528 / finished 17.09%
# processing permno 13529 / finished 17.23%
# processing permno 13532 / finished 17.36%
# processing permno 13534 / finished 17.50%
# processing permno 13537 / finished 17.63%
# processing permno 13538 / finished 17.77%
# processing permno 13539 / finished 17.90%
# processing permno 13540 / finished 18.03%
# processing permno 13541 / finished 18.17%
# processing permno 13542 / finished 18.30%
# processing permno 13543 / finished 18.44%
# processing permno 13544 / finished 18.57%
# processing permno 13545 / finished 18.71%
# processing permno 13547 / finished 18.84%
# processing permno 13548 / finished 18.98%
# processing permno 13553 / finished 19.11%
# processing permno 13554 / finished 19.25%
# processing permno 13555 / finished 19.38%
# processing permno 13556 / finished 19.52%
# processing permno 13559 / finished 19.65%
# processing permno 13561 / finished 19.78%
# processing permno 13562 / finished 19.92%
# processing permno 13563 / finished 20.05%
# processing permno 13564 / finished 20.19%
# processing permno 13567 / finished 20.32%
# processing permno 13568 / finished 20.46%
# processing permno 13569 / finished 20.59%
# processing permno 13570 / finished 20.73%
# processing permno 13571 / finished 20.86%
# processing permno 13572 / finished 21.00%
# processing permno 13575 / finished 21.13%
# processing permno 13576 / finished 21.27%
# processing permno 13577 / finished 21.40%
# processing permno 13578 / finished 21.53%
# processing permno 13579 / finished 21.67%
# processing permno 13583 / finished 21.80%
# processing permno 13584 / finished 21.94%
# processing permno 13586 / finished 22.07%
# processing permno 13594 / finished 22.21%
# processing permno 13595 / finished 22.34%
# processing permno 13597 / finished 22.48%
# processing permno 13599 / finished 22.61%
# processing permno 13600 / finished 22.75%
# processing permno 13601 / finished 22.88%
# processing permno 13604 / finished 23.01%
# processing permno 13605 / finished 23.15%
# processing permno 13606 / finished 23.28%
# processing permno 13607 / finished 23.42%
# processing permno 13608 / finished 23.55%
# processing permno 13609 / finished 23.69%
# processing permno 13610 / finished 23.82%
# processing permno 13612 / finished 23.96%
# processing permno 13613 / finished 24.09%
# processing permno 13614 / finished 24.23%
# processing permno 13615 / finished 24.36%
# processing permno 13616 / finished 24.50%
# processing permno 13617 / finished 24.63%
# processing permno 13618 / finished 24.76%
# processing permno 13619 / finished 24.90%
# processing permno 13620 / finished 25.03%
# processing permno 13621 / finished 25.17%
# processing permno 13622 / finished 25.30%
# processing permno 13623 / finished 25.44%
# processing permno 13624 / finished 25.57%
# processing permno 13625 / finished 25.71%
# processing permno 13626 / finished 25.84%
# processing permno 13627 / finished 25.98%
# processing permno 13628 / finished 26.11%
# processing permno 13631 / finished 26.24%
# processing permno 13632 / finished 26.38%
# processing permno 13633 / finished 26.51%
# processing permno 13634 / finished 26.65%
# processing permno 13636 / finished 26.78%
# processing permno 13640 / finished 26.92%
# processing permno 13641 / finished 27.05%
# processing permno 13642 / finished 27.19%
# processing permno 13643 / finished 27.32%
# processing permno 13647 / finished 27.46%
# processing permno 13648 / finished 27.59%
# processing permno 13650 / finished 27.73%
# processing permno 13652 / finished 27.86%
# processing permno 13655 / finished 27.99%
# processing permno 13656 / finished 28.13%
# processing permno 13657 / finished 28.26%
# processing permno 13658 / finished 28.40%
# processing permno 13678 / finished 28.53%
# processing permno 13679 / finished 28.67%
# processing permno 13680 / finished 28.80%
# processing permno 13681 / finished 28.94%
# processing permno 13684 / finished 29.07%
# processing permno 13685 / finished 29.21%
# processing permno 13686 / finished 29.34%
# processing permno 13687 / finished 29.48%
# processing permno 13688 / finished 29.61%
# processing permno 13690 / finished 29.74%
# processing permno 13691 / finished 29.88%
# processing permno 13692 / finished 30.01%
# processing permno 13693 / finished 30.15%
# processing permno 13694 / finished 30.28%
# processing permno 13695 / finished 30.42%
# processing permno 13698 / finished 30.55%
# processing permno 13700 / finished 30.69%
# processing permno 13701 / finished 30.82%
# processing permno 13702 / finished 30.96%
# processing permno 13704 / finished 31.09%
# processing permno 13705 / finished 31.22%
# processing permno 13706 / finished 31.36%
# processing permno 13707 / finished 31.49%
# processing permno 13711 / finished 31.63%
# processing permno 13712 / finished 31.76%
# processing permno 13713 / finished 31.90%
# processing permno 13714 / finished 32.03%
# processing permno 13721 / finished 32.17%
# processing permno 13723 / finished 32.30%
# processing permno 13724 / finished 32.44%
# processing permno 13727 / finished 32.57%
# processing permno 13728 / finished 32.71%
# processing permno 13729 / finished 32.84%
# processing permno 13730 / finished 32.97%
# processing permno 13731 / finished 33.11%
# processing permno 13732 / finished 33.24%
# processing permno 13736 / finished 33.38%
# processing permno 13737 / finished 33.51%
# processing permno 13738 / finished 33.65%
# processing permno 13739 / finished 33.78%
# processing permno 13740 / finished 33.92%
# processing permno 13743 / finished 34.05%
# processing permno 13744 / finished 34.19%
# processing permno 13745 / finished 34.32%
# processing permno 13746 / finished 34.45%
# processing permno 13747 / finished 34.59%
# processing permno 13748 / finished 34.72%
# processing permno 13749 / finished 34.86%
# processing permno 13750 / finished 34.99%
# processing permno 13751 / finished 35.13%
# processing permno 13752 / finished 35.26%
# processing permno 13753 / finished 35.40%
# processing permno 13755 / finished 35.53%
# processing permno 13756 / finished 35.67%
# processing permno 13757 / finished 35.80%
# processing permno 13758 / finished 35.94%
# processing permno 13760 / finished 36.07%
# processing permno 13761 / finished 36.20%
# processing permno 13762 / finished 36.34%
# processing permno 13763 / finished 36.47%
# processing permno 13764 / finished 36.61%
# processing permno 13765 / finished 36.74%
# processing permno 13766 / finished 36.88%
# processing permno 13767 / finished 37.01%
# processing permno 13769 / finished 37.15%
# processing permno 13770 / finished 37.28%
# processing permno 13771 / finished 37.42%
# processing permno 13772 / finished 37.55%
# processing permno 13774 / finished 37.69%
# processing permno 13775 / finished 37.82%
# processing permno 13777 / finished 37.95%
# processing permno 13779 / finished 38.09%
# processing permno 13780 / finished 38.22%
# processing permno 13781 / finished 38.36%
# processing permno 13782 / finished 38.49%
# processing permno 13783 / finished 38.63%
# processing permno 13786 / finished 38.76%
# processing permno 13787 / finished 38.90%
# processing permno 13788 / finished 39.03%
# processing permno 13789 / finished 39.17%
# processing permno 13794 / finished 39.30%
# processing permno 13795 / finished 39.43%
# processing permno 13796 / finished 39.57%
# processing permno 13797 / finished 39.70%
# processing permno 13798 / finished 39.84%
# processing permno 13799 / finished 39.97%
# processing permno 13801 / finished 40.11%
# processing permno 13802 / finished 40.24%
# processing permno 13804 / finished 40.38%
# processing permno 13807 / finished 40.51%
# processing permno 13808 / finished 40.65%
# processing permno 13809 / finished 40.78%
# processing permno 13810 / finished 40.92%
# processing permno 13811 / finished 41.05%
# processing permno 13812 / finished 41.18%
# processing permno 13815 / finished 41.32%
# processing permno 13816 / finished 41.45%
# processing permno 13817 / finished 41.59%
# processing permno 13818 / finished 41.72%
# processing permno 13819 / finished 41.86%
# processing permno 13820 / finished 41.99%
# processing permno 13823 / finished 42.13%
# processing permno 13825 / finished 42.26%
# processing permno 13826 / finished 42.40%
# processing permno 13827 / finished 42.53%
# processing permno 13828 / finished 42.66%
# processing permno 13829 / finished 42.80%
# processing permno 13830 / finished 42.93%
# processing permno 13831 / finished 43.07%
# processing permno 13833 / finished 43.20%
# processing permno 13834 / finished 43.34%
# processing permno 13835 / finished 43.47%
# processing permno 13836 / finished 43.61%
# processing permno 13837 / finished 43.74%
# processing permno 13838 / finished 43.88%
# processing permno 13839 / finished 44.01%
# processing permno 13840 / finished 44.15%
# processing permno 13842 / finished 44.28%
# processing permno 13843 / finished 44.41%
# processing permno 13844 / finished 44.55%
# processing permno 13845 / finished 44.68%
# processing permno 13846 / finished 44.82%
# processing permno 13847 / finished 44.95%
# processing permno 13850 / finished 45.09%
# processing permno 13851 / finished 45.22%
# processing permno 13852 / finished 45.36%
# processing permno 13853 / finished 45.49%
# processing permno 13854 / finished 45.63%
# processing permno 13855 / finished 45.76%
# processing permno 13856 / finished 45.90%
# processing permno 13859 / finished 46.03%
# processing permno 13860 / finished 46.16%
# processing permno 13862 / finished 46.30%
# processing permno 13863 / finished 46.43%
# processing permno 13866 / finished 46.57%
# processing permno 13867 / finished 46.70%
# processing permno 13869 / finished 46.84%
# processing permno 13870 / finished 46.97%
# processing permno 13874 / finished 47.11%
# processing permno 13875 / finished 47.24%
# processing permno 13876 / finished 47.38%
# processing permno 13877 / finished 47.51%
# processing permno 13878 / finished 47.64%
# processing permno 13879 / finished 47.78%
# processing permno 13883 / finished 47.91%
# processing permno 13885 / finished 48.05%
# processing permno 13886 / finished 48.18%
# processing permno 13887 / finished 48.32%
# processing permno 13888 / finished 48.45%
# processing permno 13889 / finished 48.59%
# processing permno 13890 / finished 48.72%
# processing permno 13894 / finished 48.86%
# processing permno 13895 / finished 48.99%
# processing permno 13896 / finished 49.13%
# processing permno 13897 / finished 49.26%
# processing permno 13898 / finished 49.39%
# processing permno 13901 / finished 49.53%
# processing permno 13903 / finished 49.66%
# processing permno 13904 / finished 49.80%
# processing permno 13905 / finished 49.93%
# processing permno 13906 / finished 50.07%
# processing permno 13907 / finished 50.20%
# processing permno 13908 / finished 50.34%
# processing permno 13909 / finished 50.47%
# processing permno 13910 / finished 50.61%
# processing permno 13911 / finished 50.74%
# processing permno 13912 / finished 50.87%
# processing permno 13913 / finished 51.01%
# processing permno 13914 / finished 51.14%
# processing permno 13915 / finished 51.28%
# processing permno 13917 / finished 51.41%
# ...
# processing permno 92810 / finished 48.99%
# processing permno 92812 / finished 49.13%
# processing permno 92813 / finished 49.26%
# processing permno 92814 / finished 49.39%
# processing permno 92816 / finished 49.53%
# processing permno 92817 / finished 49.66%
# processing permno 92818 / finished 49.80%
# processing permno 92819 / finished 49.93%
# processing permno 92820 / finished 50.07%
# processing permno 92822 / finished 50.20%
# processing permno 92824 / finished 50.34%
# processing permno 92834 / finished 50.47%
# processing permno 92835 / finished 50.61%
# processing permno 92836 / finished 50.74%
# processing permno 92837 / finished 50.87%
# processing permno 92839 / finished 51.01%
# processing permno 92840 / finished 51.14%
# processing permno 92841 / finished 51.28%
# processing permno 92842 / finished 51.41%
# processing permno 92843 / finished 51.55%
# processing permno 92844 / finished 51.68%
# processing permno 92845 / finished 51.82%
# processing permno 92846 / finished 51.95%
# processing permno 92847 / finished 52.09%
# processing permno 92848 / finished 52.22%
# processing permno 92849 / finished 52.36%
# processing permno 92852 / finished 52.49%
# processing permno 92854 / finished 52.62%
# processing permno 92855 / finished 52.76%
# processing permno 92856 / finished 52.89%
# processing permno 92857 / finished 53.03%
# processing permno 92858 / finished 53.16%
# processing permno 92859 / finished 53.30%
# processing permno 92860 / finished 53.43%
# processing permno 92862 / finished 53.57%
# processing permno 92863 / finished 53.70%
# processing permno 92864 / finished 53.84%
# processing permno 92865 / finished 53.97%
# processing permno 92870 / finished 54.10%
# processing permno 92871 / finished 54.24%
# processing permno 92872 / finished 54.37%
# processing permno 92873 / finished 54.51%
# processing permno 92876 / finished 54.64%
# processing permno 92877 / finished 54.78%
# processing permno 92878 / finished 54.91%
# processing permno 92880 / finished 55.05%
# processing permno 92881 / finished 55.18%
# processing permno 92883 / finished 55.32%
# processing permno 92884 / finished 55.45%
# processing permno 92885 / finished 55.59%
# processing permno 92886 / finished 55.72%
# processing permno 92887 / finished 55.85%
# processing permno 92888 / finished 55.99%
# processing permno 92889 / finished 56.12%
# processing permno 92890 / finished 56.26%
# processing permno 92891 / finished 56.39%
# processing permno 92892 / finished 56.53%
# processing permno 92893 / finished 56.66%
# processing permno 92894 / finished 56.80%
# processing permno 92897 / finished 56.93%
# processing permno 92898 / finished 57.07%
# processing permno 92900 / finished 57.20%
# processing permno 92901 / finished 57.34%
# processing permno 92902 / finished 57.47%
# processing permno 92904 / finished 57.60%
# processing permno 92905 / finished 57.74%
# processing permno 92906 / finished 57.87%
# processing permno 92907 / finished 58.01%
# processing permno 92908 / finished 58.14%
# processing permno 92909 / finished 58.28%
# processing permno 92910 / finished 58.41%
# processing permno 92912 / finished 58.55%
# processing permno 92913 / finished 58.68%
# processing permno 92914 / finished 58.82%
# processing permno 92916 / finished 58.95%
# processing permno 92917 / finished 59.08%
# processing permno 92918 / finished 59.22%
# processing permno 92919 / finished 59.35%
# processing permno 92922 / finished 59.49%
# processing permno 92924 / finished 59.62%
# processing permno 92927 / finished 59.76%
# processing permno 92928 / finished 59.89%
# processing permno 92929 / finished 60.03%
# processing permno 92931 / finished 60.16%
# processing permno 92933 / finished 60.30%
# processing permno 92935 / finished 60.43%
# processing permno 92936 / finished 60.57%
# processing permno 92939 / finished 60.70%
# processing permno 92940 / finished 60.83%
# processing permno 92945 / finished 60.97%
# processing permno 92948 / finished 61.10%
# processing permno 92949 / finished 61.24%
# processing permno 92950 / finished 61.37%
# processing permno 92951 / finished 61.51%
# processing permno 92952 / finished 61.64%
# processing permno 92953 / finished 61.78%
# processing permno 92955 / finished 61.91%
# processing permno 92956 / finished 62.05%
# processing permno 92957 / finished 62.18%
# processing permno 92958 / finished 62.31%
# processing permno 92959 / finished 62.45%
# processing permno 92960 / finished 62.58%
# processing permno 92961 / finished 62.72%
# processing permno 92963 / finished 62.85%
# processing permno 92964 / finished 62.99%
# processing permno 92966 / finished 63.12%
# processing permno 92967 / finished 63.26%
# processing permno 92968 / finished 63.39%
# processing permno 92969 / finished 63.53%
# processing permno 92971 / finished 63.66%
# processing permno 92972 / finished 63.80%
# processing permno 92974 / finished 63.93%
# processing permno 92976 / finished 64.06%
# processing permno 92977 / finished 64.20%
# processing permno 92980 / finished 64.33%
# processing permno 92981 / finished 64.47%
# processing permno 92984 / finished 64.60%
# processing permno 92985 / finished 64.74%
# processing permno 92986 / finished 64.87%
# processing permno 92987 / finished 65.01%
# processing permno 92993 / finished 65.14%
# processing permno 92994 / finished 65.28%
# processing permno 92995 / finished 65.41%
# processing permno 92996 / finished 65.55%
# processing permno 92999 / finished 65.68%
# processing permno 93001 / finished 65.81%
# processing permno 93002 / finished 65.95%
# processing permno 93004 / finished 66.08%
# processing permno 93010 / finished 66.22%
# processing permno 93012 / finished 66.35%
# processing permno 93013 / finished 66.49%
# processing permno 93014 / finished 66.62%
# processing permno 93016 / finished 66.76%
# processing permno 93018 / finished 66.89%
# processing permno 93021 / finished 67.03%
# processing permno 93022 / finished 67.16%
# processing permno 93023 / finished 67.29%
# processing permno 93024 / finished 67.43%
# processing permno 93026 / finished 67.56%
# processing permno 93027 / finished 67.70%
# processing permno 93028 / finished 67.83%
# processing permno 93031 / finished 67.97%
# processing permno 93032 / finished 68.10%
# processing permno 93035 / finished 68.24%
# processing permno 93036 / finished 68.37%
# processing permno 93052 / finished 68.51%
# processing permno 93053 / finished 68.64%
# processing permno 93054 / finished 68.78%
# processing permno 93055 / finished 68.91%
# processing permno 93057 / finished 69.04%
# processing permno 93058 / finished 69.18%
# processing permno 93062 / finished 69.31%
# processing permno 93063 / finished 69.45%
# processing permno 93065 / finished 69.58%
# processing permno 93067 / finished 69.72%
# processing permno 93069 / finished 69.85%
# processing permno 93070 / finished 69.99%
# processing permno 93071 / finished 70.12%
# processing permno 93073 / finished 70.26%
# processing permno 93078 / finished 70.39%
# processing permno 93079 / finished 70.52%
# processing permno 93082 / finished 70.66%
# processing permno 93083 / finished 70.79%
# processing permno 93085 / finished 70.93%
# processing permno 93087 / finished 71.06%
# processing permno 93089 / finished 71.20%
# processing permno 93093 / finished 71.33%
# processing permno 93094 / finished 71.47%
# processing permno 93095 / finished 71.60%
# processing permno 93096 / finished 71.74%
# processing permno 93098 / finished 71.87%
# processing permno 93099 / finished 72.01%
# processing permno 93101 / finished 72.14%
# processing permno 93102 / finished 72.27%
# processing permno 93103 / finished 72.41%
# processing permno 93104 / finished 72.54%
# processing permno 93106 / finished 72.68%
# processing permno 93108 / finished 72.81%
# processing permno 93109 / finished 72.95%
# processing permno 93110 / finished 73.08%
# processing permno 93112 / finished 73.22%
# processing permno 93114 / finished 73.35%
# processing permno 93115 / finished 73.49%
# processing permno 93116 / finished 73.62%
# processing permno 93117 / finished 73.76%
# processing permno 93120 / finished 73.89%
# processing permno 93122 / finished 74.02%
# processing permno 93123 / finished 74.16%
# processing permno 93126 / finished 74.29%
# processing permno 93128 / finished 74.43%
# processing permno 93130 / finished 74.56%
# processing permno 93131 / finished 74.70%
# processing permno 93132 / finished 74.83%
# processing permno 93134 / finished 74.97%
# processing permno 93137 / finished 75.10%
# processing permno 93142 / finished 75.24%
# processing permno 93143 / finished 75.37%
# processing permno 93144 / finished 75.50%
# processing permno 93145 / finished 75.64%
# processing permno 93146 / finished 75.77%
# processing permno 93147 / finished 75.91%
# processing permno 93148 / finished 76.04%
# processing permno 93149 / finished 76.18%
# processing permno 93150 / finished 76.31%
# processing permno 93151 / finished 76.45%
# processing permno 93152 / finished 76.58%
# processing permno 93153 / finished 76.72%
# processing permno 93155 / finished 76.85%
# processing permno 93157 / finished 76.99%
# processing permno 93158 / finished 77.12%
# processing permno 93159 / finished 77.25%
# processing permno 93166 / finished 77.39%
# processing permno 93167 / finished 77.52%
# processing permno 93168 / finished 77.66%
# processing permno 93169 / finished 77.79%
# processing permno 93170 / finished 77.93%
# processing permno 93171 / finished 78.06%
# processing permno 93173 / finished 78.20%
# processing permno 93174 / finished 78.33%
# processing permno 93175 / finished 78.47%
# processing permno 93177 / finished 78.60%
# processing permno 93178 / finished 78.73%
# processing permno 93179 / finished 78.87%
# processing permno 93180 / finished 79.00%
# processing permno 93181 / finished 79.14%
# processing permno 93182 / finished 79.27%
# processing permno 93183 / finished 79.41%
# processing permno 93185 / finished 79.54%
# processing permno 93186 / finished 79.68%
# processing permno 93187 / finished 79.81%
# processing permno 93188 / finished 79.95%
# processing permno 93189 / finished 80.08%
# processing permno 93190 / finished 80.22%
# processing permno 93191 / finished 80.35%
# processing permno 93200 / finished 80.48%
# processing permno 93203 / finished 80.62%
# processing permno 93204 / finished 80.75%
# processing permno 93206 / finished 80.89%
# processing permno 93207 / finished 81.02%
# processing permno 93208 / finished 81.16%
# processing permno 93210 / finished 81.29%
# processing permno 93211 / finished 81.43%
# processing permno 93212 / finished 81.56%
# processing permno 93217 / finished 81.70%
# processing permno 93218 / finished 81.83%
# processing permno 93219 / finished 81.97%
# processing permno 93221 / finished 82.10%
# processing permno 93222 / finished 82.23%
# processing permno 93223 / finished 82.37%
# processing permno 93231 / finished 82.50%
# processing permno 93233 / finished 82.64%
# processing permno 93237 / finished 82.77%
# processing permno 93239 / finished 82.91%
# processing permno 93246 / finished 83.04%
# processing permno 93248 / finished 83.18%
# processing permno 93249 / finished 83.31%
# processing permno 93251 / finished 83.45%
# processing permno 93253 / finished 83.58%
# processing permno 93254 / finished 83.71%
# processing permno 93255 / finished 83.85%
# processing permno 93256 / finished 83.98%
# processing permno 93257 / finished 84.12%
# processing permno 93258 / finished 84.25%
# processing permno 93259 / finished 84.39%
# processing permno 93260 / finished 84.52%
# processing permno 93261 / finished 84.66%
# processing permno 93262 / finished 84.79%
# processing permno 93263 / finished 84.93%
# processing permno 93264 / finished 85.06%
# processing permno 93266 / finished 85.20%
# processing permno 93267 / finished 85.33%
# processing permno 93268 / finished 85.46%
# processing permno 93269 / finished 85.60%
# processing permno 93270 / finished 85.73%
# processing permno 93272 / finished 85.87%
# processing permno 93274 / finished 86.00%
# processing permno 93275 / finished 86.14%
# processing permno 93282 / finished 86.27%
# processing permno 93283 / finished 86.41%
# processing permno 93284 / finished 86.54%
# processing permno 93285 / finished 86.68%
# processing permno 93286 / finished 86.81%
# processing permno 93288 / finished 86.94%
# processing permno 93289 / finished 87.08%
# processing permno 93291 / finished 87.21%
# processing permno 93292 / finished 87.35%
# processing permno 93293 / finished 87.48%
# processing permno 93294 / finished 87.62%
# processing permno 93295 / finished 87.75%
# processing permno 93296 / finished 87.89%
# processing permno 93299 / finished 88.02%
# processing permno 93300 / finished 88.16%
# processing permno 93301 / finished 88.29%
# processing permno 93302 / finished 88.43%
# processing permno 93303 / finished 88.56%
# processing permno 93304 / finished 88.69%
# processing permno 93305 / finished 88.83%
# processing permno 93306 / finished 88.96%
# processing permno 93309 / finished 89.10%
# processing permno 93312 / finished 89.23%
# processing permno 93313 / finished 89.37%
# processing permno 93314 / finished 89.50%
# processing permno 93318 / finished 89.64%
# processing permno 93319 / finished 89.77%
# processing permno 93325 / finished 89.91%
# processing permno 93330 / finished 90.04%
# processing permno 93331 / finished 90.17%
# processing permno 93332 / finished 90.31%
# processing permno 93333 / finished 90.44%
# processing permno 93334 / finished 90.58%
# processing permno 93335 / finished 90.71%
# processing permno 93336 / finished 90.85%
# processing permno 93337 / finished 90.98%
# processing permno 93338 / finished 91.12%
# processing permno 93339 / finished 91.25%
# processing permno 93340 / finished 91.39%
# processing permno 93341 / finished 91.52%
# processing permno 93342 / finished 91.66%
# processing permno 93343 / finished 91.79%
# processing permno 93344 / finished 91.92%
# processing permno 93345 / finished 92.06%
# processing permno 93347 / finished 92.19%
# processing permno 93350 / finished 92.33%
# processing permno 93352 / finished 92.46%
# processing permno 93354 / finished 92.60%
# processing permno 93356 / finished 92.73%
# processing permno 93357 / finished 92.87%
# processing permno 93359 / finished 93.00%
# processing permno 93360 / finished 93.14%
# processing permno 93361 / finished 93.27%
# processing permno 93362 / finished 93.41%
# processing permno 93363 / finished 93.54%
# processing permno 93364 / finished 93.67%
# processing permno 93365 / finished 93.81%
# processing permno 93366 / finished 93.94%
# processing permno 93367 / finished 94.08%
# processing permno 93368 / finished 94.21%
# processing permno 93369 / finished 94.35%
# processing permno 93370 / finished 94.48%
# processing permno 93371 / finished 94.62%
# processing permno 93372 / finished 94.75%
# processing permno 93373 / finished 94.89%
# processing permno 93374 / finished 95.02%
# processing permno 93376 / finished 95.15%
# processing permno 93377 / finished 95.29%
# processing permno 93378 / finished 95.42%
# processing permno 93379 / finished 95.56%
# processing permno 93380 / finished 95.69%
# processing permno 93381 / finished 95.83%
# processing permno 93384 / finished 95.96%
# processing permno 93385 / finished 96.10%
# processing permno 93386 / finished 96.23%
# processing permno 93393 / finished 96.37%
# processing permno 93396 / finished 96.50%
# processing permno 93397 / finished 96.64%
# processing permno 93399 / finished 96.77%
# processing permno 93400 / finished 96.90%
# processing permno 93401 / finished 97.04%
# processing permno 93406 / finished 97.17%
# processing permno 93407 / finished 97.31%
# processing permno 93408 / finished 97.44%
# processing permno 93414 / finished 97.58%
# processing permno 93415 / finished 97.71%
# processing permno 93416 / finished 97.85%
# processing permno 93417 / finished 97.98%
# processing permno 93418 / finished 98.12%
# processing permno 93419 / finished 98.25%
# processing permno 93420 / finished 98.38%
# processing permno 93421 / finished 98.52%
# processing permno 93422 / finished 98.65%
# processing permno 93423 / finished 98.79%
# processing permno 93424 / finished 98.92%
# processing permno 93425 / finished 99.06%
# processing permno 93426 / finished 99.19%
# processing permno 93427 / finished 99.33%
# processing permno 93428 / finished 99.46%
# processing permno 93429 / finished 99.60%
# processing permno 93433 / finished 99.73%
# processing permno 93434 / finished 99.87%
# processing permno 93436 / finished 100.00%
# 已处理分块 20/20
# 所有分块处理完成

# %%
# process dataframe
crsp = crsp.dropna(subset=['ill'])  # drop NA due to rolling
crsp = crsp.reset_index(drop=True)
crsp = crsp[['permno', 'date', 'ill']]

# %%
crsp.to_feather("processed_data/ill.ftr")
